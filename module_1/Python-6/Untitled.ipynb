# %%
import pandas as pd
df = pd.read_csv(r'data_sf.csv')

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 800)

# %%
Nation = df['Nationality'].value_counts()

# %%
display()

# %%
df.index

# %%
df.index[]

# %%
fc = pd.read_csv(r'data_sf.csv', index_col = 'Name')

# %%
fc

# %%
fc.index

# %%
fc = pd.read_csv(r'data_sf.csv')

# %%
small_df = df[df.columns[1:8]].head(25)

# %%
small_df.index

# %%
s = small_df['Nationality'].value_counts()
display(s)

# %%
s.index

# %%
s.index[0]

# %%
len(s.index)

# %%
s['Germany']

# %%
s.loc[s > 1]

# %%
fc = pd.read_csv(r'data_sf.csv')

# %%
fc.loc['Club']

# %%
len(fc['Club'].value_counts())

# %%
fc['Club'].value_counts()

# %%
fc['Club'].sort_index()

# %%
s = small_df['Nationality'].value_counts(normalize=True)
display(s)

# %%
position = df['Position'].value_counts(normalize=True)

# %%
display(position)

# %%
s = small_df['Wage'].value_counts(bins=4)
display(s)

# %%
small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]

# %%
small_df = df[df.columns[0:7]].head(25)

# %%
small_df

# %%
s = small_df['Wage'].value_counts(bins=4)

# %%
display(s)

# %%
s.index

# %%
s.index[3]

# %%
s.index[3].left

# %%
s.index[3].right

# %%
small_df['Wage'] > s.index[3].left

# %%
fa = df['FKAccuracy'].value_counts(bins=5)

# %%
display(fa)
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %%
s = small_df['Nationality'].value_counts()
print(s.index)
print(len(s.index))

# %%
small_df['Nationality'].unique()

# %%
len(small_df['Nationality'].unique())

# %%
small_df['Nationality'].nunique()

# %%
result = len(df['Position'].value_counts())

# %%
print(result)

# %%
something = df['Position'].value_counts()

# %%
something

# %%
something = df['Position'].count()

# %%
something

# %%
s = small_df['Nationality'].value_counts()
s_df = s.reset_index()
display(s_df)

# %%
s_df.columns = ['Nationality','Players Count']
display(s_df)

# %%
fc

# %%
spain_players_wage = fc[(fc.Nationality == 'Spain') & (fc.Wage > 40000)]

# %%
spain_players_wage
# Out:
#       Unnamed: 0             Name  Age Nationality                    Club  \
# 3              3           De Gea   27       Spain       Manchester United
# 8              8     Sergio Ramos   32       Spain             Real Madrid
# 13            13      David Silva   32       Spain         Manchester City
# 20            20  Sergio Busquets   29       Spain            FC Barcelona
# 30            30             Isco   26       Spain             Real Madrid
# 49            49       Jordi Alba   29       Spain            FC Barcelona
# 54            54            Piqué   31       Spain            FC Barcelona
# 67            67           Thiago   27       Spain       FC Bayern München
# 69            69      Azpilicueta   28       Spain                 Chelsea
# 79            79    Marco Asensio   22       Spain             Real Madrid
# 83            83             Saúl   23       Spain         Atlético Madrid
# ...

# %%
sp_pl_wa = fc['Wage'].value_counts(bins=4)

# %%
sp_pl_wa
# Out:
# (435.999, 142000.0]     12818
# (142000.0, 283000.0]       61
# (283000.0, 424000.0]       16
# (424000.0, 565000.0]        2
# Name: Wage, dtype: int64

# %%
spain_players_wage = fc[fc.Nationality == 'Spain'].Wage.value_counts(bins=4)

# %%
display(spain_players_wage)
# Out:
# (620.999, 95750.0]      651
# (95750.0, 190500.0]      11
# (190500.0, 285250.0]      6
# (285250.0, 380000.0]      3
# Name: Wage, dtype: int64

# %%
round(spain_players_wage.iloc[0]/spain_players_wage.sum()*100)
# Out:
# 97.0

# %%
print(spain_players_wage.iloc[0])
# Out:
# 651

# %%
print(spain_players_wage.sum())
# Out:
# 671

# %%
#Укажите количество национальностей (Nationality), 
#к которым относятся футболисты, выступающие за клуб (Club) "Manchester United".

mu_nationality = fc[fc.Club == 'Manchester United']

# %%
mu_nationality
# Out:
#       Unnamed: 0             Name  Age  Nationality               Club  \
# 3              3           De Gea   27        Spain  Manchester United
# 45            45         P. Pogba   25       France  Manchester United
# 47            47        R. Lukaku   25      Belgium  Manchester United
# 93            93       A. Sánchez   29        Chile  Manchester United
# 116          116       A. Martial   22       France  Manchester United
# 127          127         N. Matić   29       Serbia  Manchester United
# 231          231      M. Rashford   20      England  Manchester United
# 238          238        E. Bailly   24  Ivory Coast  Manchester United
# 263          263      C. Smalling   28      England  Manchester United
# 276          276      A. Valencia   32      Ecuador  Manchester United
# 335          336        S. Romero   31    Argentina  Manchester United
# 394          397          M. Rojo   28    Argentina  Manchester United
# ...

# %%
mu_nationality.Nationality.nunique()
# Out:
# 13

# %%
br_juve = fc[(fc.Club == 'Juventus') & (fc.Nationality == 'Brazil')]

# %%
br_juve
# Out:
#     Unnamed: 0           Name  Age Nationality      Club     Value    Wage  \
# 64          64    Alex Sandro   27      Brazil  Juventus  36500000  160000
# 65          65  Douglas Costa   27      Brazil  Juventus  46500000  175000
#
#    Position  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# 64       LB        84         55               76            81       68
# 65       LM        84         67               50            84       76
#
#     Dribbling  Curve  FKAccuracy  LongPassing  BallControl  Acceleration  \
# 64         80     78          59           71           81            83
# 65         92     84          78           68           91            97
#
#     SprintSpeed  Agility  Reactions  Balance  ShotPower  Jumping  Stamina  \
# 64           86       79         84       78         80       79       92
# 65           93       93         84       91         86       61       78
#
# ...

# %%
br_juve.index
# Out:
# Int64Index([64, 65], dtype='int64')

# %%
br_juve.Name
# Out:
# 64      Alex Sandro
# 65    Douglas Costa
# Name: Name, dtype: object

# %%
plus_35 = fc[fc.Age > 35].Club.value_counts()

# %%
plus_35
# Out:
# Hokkaido Consadole Sapporo             4
# Club Atlético Huracán                  4
# Nagoya Grampus                         3
# Club Atlético Talleres                 3
# Hammarby IF                            3
# Estudiantes de La Plata                3
# Club Atlético Colón                    3
# Gimnasia y Esgrima La Plata            3
# Morecambe                              3
# Club Atlético Tigre                    3
# Benevento                              3
# San Martín de San Juan                 3
# Lobos BUAP                             2
# Unión La Calera                        2
# Kashima Antlers                        2
# FC Zürich                              2
# Once Caldas                            2
# Chievo Verona                          2
# Parma                                  2
# Elche CF                               2
# Júbilo Iwata                           2
# SK Brann                               2
# Cork City                              2
# ...

# %%
ar_age = fc[fc.Nationality == 'Argentina'].Age.value_counts(bins=4)

# %%
ar_age
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %%
sp_age_21 = fc[(fc.Nationality == 'Spain') & (fc.Age == 21)].nunique()

# %%
sp_age_21
# Out:
# Unnamed: 0         79
# Name               79
# Age                 1
# Nationality         1
# Club               43
# Value              41
# Wage               15
# Position           15
# Crossing           47
# Finishing          53
# HeadingAccuracy    33
# ShortPassing       44
# Volleys            45
# Dribbling          46
# Curve              39
# FKAccuracy         41
# LongPassing        43
# BallControl        42
# Acceleration       32
# SprintSpeed        39
# Agility            44
# Reactions          29
# Balance            40
# ShotPower          42
# Jumping            33
# Stamina            39
# Strength           33
# LongShots          47
# Aggression         43
# Interceptions      41
# Positioning        40
# Vision             40
# Penalties          38
# Composure          38
# Marking            41
# StandingTackle     40
# SlidingTackle      37
# GKDiving           20
# GKHandling         19
# GKKicking          22
# GKPositioning      22
# ...

# %%
round(fc[fc.Nationality == 'Spain'].Age.value_counts(normalize=True)[21] * 100, 2)
# Out:
# 11.77

# %%
import pandas as pd
df = pd.read_csv(r'data_sf.csv')

# %%
df.groupby(['Club'])

# %%
df.groupby(['Club']).groups
# Out:
# {' SSV Jahn Regensburg': Int64Index([ 1642,  2284,  2374,  2401,  2575,  2583,  2850,  2868,  3418,
#               3908,  3989,  4154,  5151,  5177,  5525,  5885,  6070,  6679,
#               7173,  7477,  8905,  9061, 10825, 12482],
#             dtype='int64'),
#  '1. FC Heidenheim 1846': Int64Index([ 1060,  1805,  1978,  2050,  2066,  2926,  3584,  3605,  4312,
#               4457,  4783,  6818,  7160,  7166,  7460,  9475, 10052, 10565,
#              11217, 12236],
#             dtype='int64'),
#  '1. FC Kaiserslautern': Int64Index([ 2931,  3590,  4270,  4413,  4475,  4483,  4709,  4779,  5079,
#               5325,  5403,  5855,  5917,  7295,  8784,  9496,  9964, 10019,
#              10122, 10671, 11500, 11970, 12222],
#             dtype='int64'),
#  '1. FC Köln': Int64Index([166, 379, 899, 1399, 3415, 6904, 7052, 8892, 12171, 12376], dtype='int64'),
#  '1. FC Magdeburg': Int64Index([ 1967,  2069,  2152,  2569,  2886,  3030,  3300,  3332,  4436,
# ...

# %%
grouped_df = df.groupby(['Club']).sum()
display(grouped_df)
# Out:
#                        Unnamed: 0  Age     Value    Wage  Crossing  Finishing  \
# Club
#  SSV Jahn Regensburg       129124  609  15195000   90000      1104        944
# 1. FC Heidenheim 1846      117834  473  18290000   76000       961        860
# 1. FC Kaiserslautern       167351  544  11195000   33000      1106        918
# 1. FC Köln                  54865  225  46810000   92000       444        357
# 1. FC Magdeburg            116731  515  57525000   84000       948        903
# ...                           ...  ...       ...     ...       ...        ...
# Zagłębie Sosnowiec         220803  656   6815000   27000      1161       1007
# Çaykur Rizespor            119137  557  27515000  118000      1110        921
# Örebro SK                  224465  622   8465000   36000      1114        974
# Östersunds FK              136103  478  11030000   39000       944        805
# Śląsk Wrocław              172358  628   9170000   50000      1058       1054
#
# ...

# %%
grouped_df.loc['Ajax']
# Out:
# Unnamed: 0             26041
# Age                      275
# Value              152250000
# Wage                  158000
# Crossing                 844
# Finishing                723
# HeadingAccuracy          848
# ShortPassing             940
# Volleys                  696
# Dribbling                932
# Curve                    779
# FKAccuracy               680
# LongPassing              878
# BallControl              951
# Acceleration             944
# SprintSpeed              969
# Agility                  969
# Reactions                924
# Balance                  918
# ShotPower                876
# Jumping                  915
# Stamina                  974
# Strength                 896
# LongShots                720
# Aggression               847
# Interceptions            801
# Positioning              813
# Vision                   881
# Penalties                710
# Composure                929
# Marking                  750
# StandingTackle           814
# ...

# %%
grouped_df.loc['Ajax']['Wage']
# Out:
# 158000

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum()
display(grouped_df)
# Out:
# Club
#  SSV Jahn Regensburg      90000
# 1. FC Heidenheim 1846     76000
# 1. FC Kaiserslautern      33000
# 1. FC Köln                92000
# 1. FC Magdeburg           84000
#                           ...
# Zagłębie Sosnowiec        27000
# Çaykur Rizespor          118000
# Örebro SK                 36000
# Östersunds FK             39000
# Śląsk Wrocław             50000
# Name: Wage, Length: 650, dtype: int64

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum().sort_values(ascending=False)
print(grouped_df.head(5))
# Out:
# Club
# Real Madrid          4138000
# FC Barcelona         3967000
# Manchester City      3097000
# Manchester United    2357000
# Juventus             2335000
# Name: Wage, dtype: int64

# %%
# Отметьте позиции (Position), по которым общая сумма зарплат (Wage) игроков превышает 5 млн евро в год.

# %%
group_position_wage = df.groupby(['Position'])['Wage'].sum().sort_values(ascending=False) > 5000000
print(group_position_wage.head(10))
# Out:
# Position
# ST      True
# GK      True
# CB      True
# CM      True
# LB      True
# CAM     True
# LM      True
# RM      True
# RB      True
# CDM    False
# Name: Wage, dtype: bool

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()
# Out:
#                      Wage        Age  ShotPower
# Nationality
# Afghanistan   1250.000000  22.500000  53.750000
# Albania       5931.034483  23.689655  54.551724
# Algeria      15810.810811  27.027027  56.567568
# Andorra       1000.000000  28.000000  58.000000
# Angola        7100.000000  24.700000  63.700000
# ...                   ...        ...        ...
# Uzbekistan    9000.000000  29.500000  71.500000
# Venezuela     6611.111111  23.638889  57.222222
# Wales         9529.411765  24.754902  48.558824
# Zambia        2833.333333  21.833333  66.833333
# Zimbabwe      5000.000000  26.555556  62.888889
#
# [156 rows x 3 columns]

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean().sort_values(['Wage'],ascending=False).head(10)
# Out:
#                             Wage        Age  ShotPower
# Nationality
# Dominican Republic  71000.000000  23.000000  75.500000
# Egypt               35545.454545  25.818182  59.363636
# Gabon               28900.000000  26.400000  56.900000
# Croatia             26722.222222  24.819444  54.305556
# Equatorial Guinea   25666.666667  28.000000  55.333333
# Belgium             20024.390244  24.030488  56.390244
# Ecuador             18333.333333  24.619048  60.666667
# Uruguay             17590.361446  26.771084  56.192771
# Brazil              17371.158392  27.898345  58.203310
# Algeria             15810.810811  27.027027  56.567568

# %%
df.loc[df['Nationality'] == 'Dominican Republic'][['Name','Club','Wage','Age','ShotPower']]
# Out:
#             Name         Club    Wage  Age  ShotPower
# 291      Mariano  Real Madrid  140000   24         85
# 6279  L. Quezada   Córdoba CF    2000   22         66

# %%
# Посчитайте среднюю зарплату (Wage) и цену (Value) игроков разных позиций (Position). 
# Представители какой позиции имеют самую высокую среднюю ценность?

df.groupby(['Position'])[['Wage', 'Value']].mean().sort_values(['Wage'], ascending=False).head(10)
# Out:
#                    Wage         Value
# Position
# RF        119000.000000  2.636583e+07
# LF         75125.000000  2.736250e+07
# LAM        61000.000000  1.324583e+07
# LS         15421.487603  5.848430e+06
# RW         13822.784810  3.495738e+06
# RCM        13504.166667  4.217604e+06
# LCM        13497.854077  4.318090e+06
# RS         13482.456140  3.645833e+06
# LW         12169.421488  3.603099e+06
# RAM        11800.000000  8.345000e+06

# %%
df.groupby(['Nationality'])[['Club','Name']].nunique()
# Out:
#              Club  Name
# Nationality
# Afghanistan     4     4
# Albania        26    29
# Algeria        33    37
# Andorra         1     1
# Angola          9    10
# ...           ...   ...
# Uzbekistan      2     2
# Venezuela      34    36
# Wales          56   101
# Zambia          5     6
# Zimbabwe        8     9
#
# [156 rows x 2 columns]

# %%
df.groupby(['Club'])['Name'].count()
# Out:
# Club
#  SSV Jahn Regensburg     24
# 1. FC Heidenheim 1846    20
# 1. FC Kaiserslautern     23
# 1. FC Köln               10
# 1. FC Magdeburg          21
#                          ..
# Zagłębie Sosnowiec       25
# Çaykur Rizespor          22
# Örebro SK                26
# Östersunds FK            20
# Śląsk Wrocław            24
# Name: Name, Length: 650, dtype: int64

# %%
df.groupby(['Club'])['Dribbling'].median()
# Out:
# Club
#  SSV Jahn Regensburg     57.5
# 1. FC Heidenheim 1846    59.5
# 1. FC Kaiserslautern     54.0
# 1. FC Köln               60.5
# 1. FC Magdeburg          53.0
#                          ...
# Zagłębie Sosnowiec       58.0
# Çaykur Rizespor          62.0
# Örebro SK                55.0
# Östersunds FK            61.5
# Śląsk Wrocław            54.5
# Name: Dribbling, Length: 650, dtype: float64

# %%
df.groupby(['Club'])['Strength'].max()
# Out:
# Club
#  SSV Jahn Regensburg     92
# 1. FC Heidenheim 1846    86
# 1. FC Kaiserslautern     85
# 1. FC Köln               76
# 1. FC Magdeburg          86
#                          ..
# Zagłębie Sosnowiec       84
# Çaykur Rizespor          81
# Örebro SK                85
# Östersunds FK            88
# Śląsk Wrocław            85
# Name: Strength, Length: 650, dtype: int64

# %%
df.groupby(['Club'])['Balance'].min()
# Out:
# Club
#  SSV Jahn Regensburg     29
# 1. FC Heidenheim 1846    22
# 1. FC Kaiserslautern     29
# 1. FC Köln               31
# 1. FC Magdeburg          19
#                          ..
# Zagłębie Sosnowiec       28
# Çaykur Rizespor          39
# Örebro SK                34
# Östersunds FK            32
# Śląsk Wrocław            31
# Name: Balance, Length: 650, dtype: int64

# %%
# Посчитайте среднюю (mean) и медианную (median) зарплату (Wage) футболистов из разных клубов (Club). 
# В скольких клубах средняя и медианная зарплаты совпадают?

# Подсказка: чтобы в процессе группировки применить к данным одновременно две агрегирующие функции, 
# необходимо указать их как аргументы метода agg:

# df.groupby(столбец_для_группировки)[столбцы_для_отображения].agg(['функция_1', 'функция_2'])

# %%
f = df.groupby(['Club'])['Wage'].agg(['mean', 'median'])

d = (f['mean'] == f['median']).sum() 

d
# Out:
# 52

# %%
s = df.groupby(['Club'])['Wage'].agg(['mean', 'median' ])
df['comparison']=(s['mean']==s['median'])
df.loc[df['comparison'] == True].head(100)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Age, Nationality, Club, Value, Wage, Position, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, comparison]
# Index: []
#
# [0 rows x 43 columns]

# %%
df.median()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1076: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Unnamed: 0           6622.0
# Age                    24.0
# Value              500000.0
# Wage                 2000.0
# Crossing               51.0
# Finishing              45.0
# HeadingAccuracy        54.0
# ShortPassing           60.0
# Volleys                41.0
# Dribbling              58.0
# Curve                  45.0
# FKAccuracy             39.0
# LongPassing            53.0
# BallControl            60.0
# Acceleration           66.0
# SprintSpeed            66.0
# Agility                64.0
# Reactions              59.0
# Balance                65.0
# ShotPower              56.0
# Jumping                65.0
# Stamina                64.0
# Strength               65.0
# LongShots              47.0
# Aggression             56.0
# Interceptions          51.0
# Positioning            52.0
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
df['Wage'].count()
# Out:
# 12897

# %%
df['Dribbling'].value_counts(ascending=True)
# Out:
# 95      1
# 94      1
# 93      1
# 97      1
# 96      1
#      ...
# 60    458
# 65    490
# 62    522
# 63    538
# 64    545
# Name: Dribbling, Length: 94, dtype: int64

# %%
df['Club'].value_counts(normalize=True)
# Out:
# V-Varen Nagasaki     0.002326
# Shonan Bellmare      0.002326
# Vissel Kobe          0.002249
# FC Emmen             0.002249
# Padova               0.002249
#                        ...
# Cruzeiro             0.000620
# GD Chaves            0.000543
# Vitória Guimarães    0.000543
# Dinamo Zagreb        0.000543
# Atlético Mineiro     0.000465
# Name: Club, Length: 650, dtype: float64

# %%
df['Nationality'].value_counts()
# Out:
# England        1368
# Germany         919
# Spain           671
# France          614
# Argentina       574
#                ...
# Lebanon           1
# Philippines       1
# Oman              1
# Malta             1
# Nicaragua         1
# Name: Nationality, Length: 156, dtype: int64

# %%
group_club = df.groupby(['Club'])

# %%
group_club.get_group('Liverpool')
# Out:
#        Unnamed: 0                 Name  Age  Nationality       Club     Value  \
# 26             26             M. Salah   26        Egypt  Liverpool  69500000
# 58             58              S. Mané   26      Senegal  Liverpool  52000000
# 59             59          V. van Dijk   26  Netherlands  Liverpool  44500000
# 61             61      Roberto Firmino   26       Brazil  Liverpool  53000000
# 81             81              Alisson   25       Brazil  Liverpool  36500000
# 118           118              Fabinho   24       Brazil  Liverpool  34000000
# 144           144             N. Keïta   23       Guinea  Liverpool  34000000
# 219           219         J. Henderson   28      England  Liverpool  18000000
# 222           222         G. Wijnaldum   27  Netherlands  Liverpool  23000000
# 259           259            D. Lovren   28      Croatia  Liverpool  16000000
# 261           261           X. Shaqiri   26  Switzerland  Liverpool  19000000
# ...

# %%
filt = df['Club'] == 'Liverpool'
df.loc[filt]['Position'].value_counts()
# Out:
# Series([], Name: Position, dtype: int64)

# %%
group_club['Wage'].value_counts().head(100)
# Out:
# Club                  Wage
#  SSV Jahn Regensburg  3000     7
#                       4000     5
#                       2000     4
#                       5000     4
#                       6000     2
#                               ..
# AS Béziers            4000     1
# AS Monaco             8000     2
#                       61000    2
#                       2000     1
#                       4000     1
# Name: Wage, Length: 100, dtype: int64

# %%
group_club['Wage'].value_counts().loc['Liverpool']
# Out:
# Wage
# 7000      3
# 8000      2
# 76000     2
# 115000    2
# 120000    2
# 130000    2
# 195000    2
# 3000      1
# 9000      1
# 17000     1
# 36000     1
# 62000     1
# 83000     1
# 99000     1
# 125000    1
# 165000    1
# 255000    1
# Name: Wage, dtype: int64

# %%
group_nation = df.groupby(['Nationality'])

# %%
group_nation['Wage'].value_counts(ascending=False).loc['England']
# Out:
# Wage
# 1000      348
# 2000      329
# 3000      232
# 4000      143
# 5000       71
#          ...
# 115000      1
# 125000      1
# 130000      1
# 195000      1
# 205000      1
# Name: Wage, Length: 64, dtype: int64

# %%
group_position = df.groupby(['Position'])

# %%
group_position['Club'].value_counts().loc['RWB']
# Out:
# Club
# Bury                             4
# FC Midtjylland                   3
# Mansfield Town                   3
# Sheffield United                 3
# Vejle Boldklub                   3
# Wolverhampton Wanderers          3
# AIK                              2
# FC Erzgebirge Aue                2
# FC Nordsjælland                  2
# IFK Göteborg                     2
# Milton Keynes Dons               2
# Newport County                   2
# TSG 1899 Hoffenheim              2
# Örebro SK                        2
# Al Fayha                         1
# Blackpool                        1
# Bray Wanderers                   1
# Central Coast Mariners           1
# Changchun Yatai FC               1
# Cheltenham Town                  1
# Crawley Town                     1
# De Graafschap                    1
# Everton                          1
# FC Energie Cottbus               1
# FC Lugano                        1
# FC Schalke 04                    1
# ...

# %%
#group_nation['Wage'].value_counts(ascending=False).loc['England']

group_nation['Wage'].agg(['max', 'median', 'sum', 'count']).loc['England']
# Out:
# max        205000
# median       3000
# sum       8294000
# count        1368
# Name: England, dtype: int64

# %%
f = df.groupby(['Club'])['Wage'].agg(['mean', 'median', 'max'])

d = (f['mean'] == f['median'])

c = (f.loc[(f['mean'] == f['median'])])
c.sort_values('max', ascending=False)
c
# Out:
#                            mean  median    max
# Club
# 1. FC Magdeburg          4000.0    4000   8000
# AEK Athens               1000.0    1000   1000
# AJ Auxerre               2000.0    2000   4000
# Benevento                2000.0    2000   4000
# Bohemian FC              1000.0    1000   1000
# Boyacá Chicó FC          1000.0    1000   1000
# Bray Wanderers           1000.0    1000   1000
# Brøndby IF               6000.0    6000  21000
# CD Feirense              4000.0    4000  11000
# CD Tondela               2000.0    2000   4000
# Cork City                1000.0    1000   1000
# Cruzeiro                13000.0   13000  18000
# Deportivo Pasto          1000.0    1000   1000
# Dinamo Zagreb            1000.0    1000   1000
# Dundalk                  1000.0    1000   1000
# Dynamo Kyiv              1000.0    1000   1000
# Envigado FC              1000.0    1000   1000
# FC Energie Cottbus       1000.0    1000   1000
# FC Metz                  1500.0    1500   2000
# ...

# %%
small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-144-fa8faa724d35> in <module>
# ----> 1 small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
#
# NameError: name 'small_df' is not defined

# %%
# С помощью функции groupby посчитайте сумму зарплат (Wage) футболистов клуба (Club) "Chelsea"
#  = df.groupby(['Club'])['Wage'].agg(['mean', 'median', 'max'])

chealsea_wage = df.groupby(['Club'])['Wage']

# %%
chealsea_wage.get_group('Chelsea').sum()
# Out:
# 2035000

# %%
chealsea_wage['Club'].value_counts().loc['Chealsea']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Chealsea'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-153-d8aafef441e9> in <module>
# ...

# %%
group_position['Club'].value_counts().loc['RWB']
# Out:
# Club
# Bury                             4
# FC Midtjylland                   3
# Mansfield Town                   3
# Sheffield United                 3
# Vejle Boldklub                   3
# Wolverhampton Wanderers          3
# AIK                              2
# FC Erzgebirge Aue                2
# FC Nordsjælland                  2
# IFK Göteborg                     2
# Milton Keynes Dons               2
# Newport County                   2
# TSG 1899 Hoffenheim              2
# Örebro SK                        2
# Al Fayha                         1
# Blackpool                        1
# Bray Wanderers                   1
# Central Coast Mariners           1
# Changchun Yatai FC               1
# Cheltenham Town                  1
# Crawley Town                     1
# De Graafschap                    1
# Everton                          1
# FC Energie Cottbus               1
# FC Lugano                        1
# FC Schalke 04                    1
# ...

# %%
# Определите максимальную зарплату футболиста национальности (Nationality) Аргентина ("Argentina") в возрасте 20 лет

# %%
group_nation = df.groupby(['Nationality'])['Age', 'Wage']

# %%
b = group_nation.get_group('Argentina')

# %%
filtered = (b['Age'] == 20 & b['Wage'] == max())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-202-3788a22ef841> in <module>
# ----> 1 filtered = (b['Age'] == 20 & b['Wage'] == max())
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
f = df.groupby(['Nationality'])['Wage', 'Age'].agg(['max'])

# %%
# Out:
#                Wage Age
#                 max max
# Nationality
# Afghanistan    2000  26
# Albania       58000  34
# Algeria      205000  35
# Andorra        1000  28
# Angola        44000  30
# ...             ...  ..
# Uzbekistan    17000  30
# Venezuela     42000  34
# Wales        355000  37
# Zambia         6000  28
# Zimbabwe      20000  34
#
# [156 rows x 2 columns]

# %%
filt = df['Nationality'] == 'Argentina'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12892    False
# 12893    False
# 12894    False
# 12895    False
# 12896    False
# Name: Nationality, Length: 12897, dtype: bool

# %%
filt
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12892    False
# 12893    False
# 12894    False
# 12895    False
# 12896    False
# Name: Club, Length: 12897, dtype: bool

# %%
group_nation = df.groupby(['Nationality'])

# %%
argentina_scheme = group_nation.get_group('Argentina')

# %%
argentina_scheme
# Out:
#        Unnamed: 0            Name  Age Nationality  \
# 0               0        L. Messi   31   Argentina
# 15             15       P. Dybala   24   Argentina
# 23             23       S. Agüero   30   Argentina
# 38             38      G. Higuaín   30   Argentina
# 43             43       M. Icardi   25   Argentina
# ...           ...             ...  ...         ...
# 12050       12279        T. Durso   19   Argentina
# 12056       12285      V. Barbero   17   Argentina
# 12335       12564      E. Alarcón   25   Argentina
# 12556       12785   F. Bustamante   19   Argentina
# 12681       12910  L. Finochietto   21   Argentina
#
#                               Club      Value    Wage Position  Crossing  \
# 0                     FC Barcelona  110500000  565000       RF        84
# 15                        Juventus   89000000  205000       LF        82
# 23                 Manchester City   64500000  300000       ST        70
# ...

# %%
argentina_scheme.sort_values(by='Age')
# Out:
#        Unnamed: 0          Name  Age Nationality                     Club  \
# 11882       12109      R. Gómez   16   Argentina      Belgrano de Córdoba
# 9716         9920     B. Galván   17   Argentina      Club Atlético Colón
# 12056       12285    V. Barbero   17   Argentina      Belgrano de Córdoba
# 9944        10150      B. Garré   17   Argentina          Manchester City
# 10169       10380     V. Burgoa   17   Argentina               Godoy Cruz
# ...           ...           ...  ...         ...                      ...
# 2337         2451    J. Speroni   39   Argentina           Crystal Palace
# 1519         1576  N. Fernández   39   Argentina        Unión de Santa Fe
# 5341         5502    M. Caranta   39   Argentina   Club Atlético Talleres
# 1612         1677     F. Cubero   39   Argentina          Vélez Sarsfield
# 1674         1745      R. Braña   39   Argentina  Estudiantes de La Plata
#
#          Value  Wage Position  Crossing  Finishing  ...  Composure  Marking  \
# ...

# %%
argentina_scheme[['Age', 'Wage']]
# Out:
#        Age   Wage
# 11882   16   1000
# 10758   17   1000
# 10394   17   1000
# 10192   17   1000
# 10812   17   1000
# ...    ...    ...
# 1018    39  10000
# 1542    40   4000
# 723     40   2000
# 1290    40   6000
# 2604    41   1000
#
# [574 rows x 2 columns]

# %%
argentina_scheme.sort_values(by=['Age', 'Wage'], ascending=[True, False])
# Out:
#        Unnamed: 0               Name  Age Nationality  \
# 11882       12109           R. Gómez   16   Argentina
# 9944        10150           B. Garré   17   Argentina
# 10758       10977          A. Manzur   17   Argentina
# 10394       10608         A. Barreal   17   Argentina
# 10192       10404           G. Verón   17   Argentina
# 10812       11031          J. Romero   17   Argentina
# 9694         9898          T. Almada   17   Argentina
# 10169       10380          V. Burgoa   17   Argentina
# 12056       12285         V. Barbero   17   Argentina
# 9938        10144        E. Bullaude   17   Argentina
# 9716         9920          B. Galván   17   Argentina
# 8367         8558        A. Almendra   18   Argentina
# 9138         9338        C. Ferreira   18   Argentina
# 9823        10028         J. Álvarez   18   Argentina
# 9004         9202      N. Andereggen   18   Argentina
# 9909        10114          M. Molina   18   Argentina
# ...

# %%
filt = (argentina_scheme['Age'] == 20)

# %%
argentina_scheme[filt].sort_values(by=['Wage'], ascending=[False])
# Out:
#        Unnamed: 0           Name  Age Nationality  \
# 356           358    L. Martínez   20   Argentina
# 1460         1511     M. Zaracho   20   Argentina
# 2037         2136     N. Barrios   20   Argentina
# 1477         1531    L. Martínez   20   Argentina
# 4261         4409      N. Molina   20   Argentina
# 7419         7604    I. Huguenet   20   Argentina
# 5368         5530        D. Sosa   20   Argentina
# 7740         7928    T. Conechny   20   Argentina
# 5072         5230    I. Erquiaga   20   Argentina
# 8723         8916  W. Bracamonte   20   Argentina
# 8766         8959     F. Sivetti   20   Argentina
# 9057         9255      F. Quiroz   20   Argentina
# 8423         8615     A. Verdugo   20   Argentina
# 10846       11065      D. Becker   20   Argentina
# 8722         8915      J. Méndez   20   Argentina
# 10772       10991      I. Bolaño   20   Argentina
# 10811       11030       F. Marín   20   Argentina
# 9025         9223       E. Ojeda   20   Argentina
# ...

# %%
# Определите максимальную силу (Strength) и баланс (Balance) 
# среди игроков клуба (Club) "FC Barcelona" из Аргентины ("Argentina"). 
# Ответ введите через точку с запятой без пробела.

clubs = df.groupby(['Club'])
barcelona = clubs.get_group('FC Barcelona')
barcelona_str_bal_nation = barcelona[['Name', 'Strength', 'Balance', 'Nationality']]
filt = (barcelona_str_bal_nation['Nationality'] == 'Argentina')
barcelona_str_bal_nation[filt]
# Out:
#        Name  Strength  Balance Nationality
# 0  L. Messi        59       95   Argentina

# %%
barcelona_str_bal
# Out:
#                  Name  Strength  Balance  Nationality
# 0            L. Messi        59       95    Argentina
# 7           L. Suárez        83       83      Uruguay
# 18      M. ter Stegen        79       43      Germany
# 20    Sergio Busquets        77       52        Spain
# 32           Coutinho        61       93       Brazil
# 42          S. Umtiti        84       66       France
# 49         Jordi Alba        61       85        Spain
# 53         I. Rakitić        66       66      Croatia
# 54              Piqué        83       36        Spain
# 96           A. Vidal        79       75        Chile
# 141        O. Dembélé        46       85       France
# 190            Arthur        62       86       Brazil
# 195        C. Lenglet        80       60       France
# 204      J. Cillessen        67       50  Netherlands
# 235     Nélson Semedo        62       83     Portugal
# 605      T. Vermaelen        79       56      Belgium
# ...

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum')
display(pivot)
# Out:
#                            Wage
# Club               FC Barcelona  Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0  205000.0          206000.0         NaN
# Belgium                110000.0       NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN  180000.0               NaN         NaN
# Brazil                 465000.0  335000.0           91000.0    570000.0
# Chile                  205000.0       NaN          215000.0         NaN
# Costa Rica                  NaN       NaN               NaN    195000.0
# Croatia                260000.0  160000.0               NaN    420000.0
# Dominican Republic          NaN       NaN               NaN    140000.0
# Ecuador                     NaN       NaN          120000.0         NaN
# England                     NaN       NaN          478000.0         NaN
# France                 495000.0  145000.0          375000.0    459000.0
# ...

# %%
df = pd.read_csv('data_sf.csv')
club = df[(df.Nationality == 'Spain')&(df.Club == 'FC Barcelona')]
club[club.Strength==club.Strength.max()][['Strength','Balance','Name']]
# Out:
#     Strength  Balance   Name
# 54        83       36  Piqué

# %%
df = pd.read_csv('data_sf.csv')
club = df[(df.Nationality == 'Spain')&(df.Club == 'FC Barcelona')]
club[club.Strength==club.Strength.max()][['Strength','Balance','Name']]
club[club.Balance==club.Balance.max()][['Strength','Balance','Name']]
# Out:
#     Strength  Balance        Name
# 49        61       85  Jordi Alba

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
margins=True,
fill_value=0)
display(pivot)
# Out:
#                            Wage                                         \
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                565000   205000            206000           0
# Belgium                  110000        0            230000      240000
# Bosnia Herzegovina            0   180000                 0           0
# Brazil                   465000   335000             91000      570000
# Chile                    205000        0            215000           0
# Costa Rica                    0        0                 0      195000
# Croatia                  260000   160000                 0      420000
# Dominican Republic            0        0                 0      140000
# Ecuador                       0        0            120000           0
# England                       0        0            478000           0
# France                   495000   145000            375000      459000
# ...

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Name'],
index=['Nationality'],
columns=['Club'],
aggfunc='count',
fill_value=0)
display(pivot)
# Out:
#                            Name
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                     1        1                 2           0
# Belgium                       1        0                 1           1
# Bosnia Herzegovina            0        1                 0           0
# Brazil                        2        2                 1           2
# Chile                         1        0                 1           0
# Costa Rica                    0        0                 0           1
# Croatia                       1        1                 0           1
# Dominican Republic            0        0                 0           1
# Ecuador                       0        0                 1           0
# England                       0        0                 6           0
# France                        3        1                 2           3
# Germany                       1        1                 0           1
# ...

# %%
pivot.loc['Argentina']['Name']['Manchester United']
# Out:
# 2

# %%
pivot_1 = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Name'],
index=['Club'],
columns=['Position'],
aggfunc='count',
fill_value=0)
                 
                 
display(pivot_1)
# Out:
#                   Name                                                        \
# Position           CAM CB CDM CM GK LB LCB LCM LF LM LW RB RCB RCM RDM RF RM
# Club
# FC Barcelona         1  4   1  1  4  1   1   1  0  0  1  1   1   1   0  1  0
# Juventus             0  1   1  0  1  2   1   0  1  3  0  0   1   1   0  0  0
# Manchester United    0  5   1  2  2  2   0   0  0  0  2  0   1   0   1  0  1
# Real Madrid          0  1   2  1  3  2   0   2  0  0  1  1   2   1   0  0  0
#
#
# Position          RS RW ST
# Club
# FC Barcelona       1  2  0
# Juventus           0  0  2
# Manchester United  0  1  2
# Real Madrid        0  2  4

# %%
pivot2 = df.pivot_table(columns = 'Position', index = 'Club', values = 'Name', aggfunc = 'count', fill_value=0)

# %%
pivot2
# Out:
# Position                             CAM  CB  CDM  CF  CM  GK  LAM  LB  LCB  \
# Club
#  SSV Jahn Regensburg                   0   5    1   0   2   3    0   2    0
# 1. FC Heidenheim 1846                  1   3    0   0   1   2    0   2    1
# 1. FC Kaiserslautern                   0   3    3   0   0   3    0   2    1
# 1. FC Köln                             0   1    1   0   2   3    0   0    0
# 1. FC Magdeburg                        0   4    0   1   0   3    0   1    1
# 1. FC Nürnberg                         1   1    2   0   1   1    0   1    0
# 1. FC Union Berlin                     1   2    2   0   1   1    0   2    1
# 1. FSV Mainz 05                        0   2    0   0   1   1    0   1    0
# AC Ajaccio                             3   1    0   0   1   1    0   3    1
# AC Horsens                             0   3    1   0   2   3    0   3    1
# AD Alcorcón                            0   3    1   0   1   1    0   2    1
# ...

# %%
pivot2['GK'].mean()
# Out:
# 2.5246153846153847

# %%
# Используя таблицу, созданную на предыдущем шаге, определите, 
# сколько клубов не содержат данных о центральных полузащитниках. (CM)

filt = (pivot2['CM'] == 0)

# %%
len(pivot2[filt])
# Out:
# 136

# %%
# С помощью сводной таблицы и функции loc посчитайте, 
# сколько получают ("Wage") русские футболисты ("Russia"), играющие за ФК "AS Monaco".

# %%
pivot3 = df.pivot_table(values=['Name'],
index=['Nationality'],
columns=['Club'],
aggfunc='count',
fill_value=0)
display(pivot3)
# Out:
#                                      Name                        \
# Club                  SSV Jahn Regensburg 1. FC Heidenheim 1846
# Nationality
# Afghanistan                             0                     0
# Albania                                 0                     0
# Algeria                                 0                     0
# Andorra                                 0                     0
# Angola                                  0                     0
# Antigua & Barbuda                       0                     0
# Argentina                               0                     0
# Armenia                                 0                     0
# Australia                               0                     0
# Austria                                 0                     0
# Azerbaijan                              0                     0
# Barbados                                0                     0
# ...

# %%
pivot4 = df.loc[df['Club'].isin(['AS Monaco'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Name'],
aggfunc='sum',
margins=True,
fill_value=0)
                 
display(pivot4)
# Out:
#                   Wage                                                      \
# Name        A. Golovin A. Raggi B. Badiashile D. Sidibé D. Subašić  Falcao
# Nationality
# Belgium              0        0             0         0          0       0
# Brazil               0        0             0         0          0       0
# Colombia             0        0             0         0          0  115000
# Croatia              0        0             0         0      70000       0
# France               0        0          4000     61000          0       0
# Italy                0    48000             0         0          0       0
# Montenegro           0        0             0         0          0       0
# Morocco              0        0             0         0          0       0
# Poland               0        0             0         0          0       0
# Portugal             0        0             0         0          0       0
# ...

# %%
f  = df.pivot_table(columns = 'Position', index = 'Club', values = 'SprintSpeed', aggfunc = 'mean', fill_value=0)
f.max().sort_values( ascending=False )
# Out:
# Position
# RS     94.0
# RM     94.0
# LM     94.0
# LS     93.0
# RB     93.0
# LB     93.0
# CF     91.0
# LW     91.0
# ST     91.0
# RDM    91.0
# RW     91.0
# RCM    90.0
# CAM    89.0
# LF     88.0
# RCB    88.0
# LCB    88.0
# RWB    86.0
# RF     86.0
# CM     86.0
# LWB    86.0
# LAM    85.0
# LCM    84.0
# CDM    83.0
# LDM    79.0
# RAM    78.0
# CB     78.0
# GK     62.0
# dtype: float64

# %%
pivot4 = df.loc[df['Club'].isin(['AS Monaco'])]

# %%
pivot4
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Age, Nationality, Club, Value, Wage, Position, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes]
# Index: []
