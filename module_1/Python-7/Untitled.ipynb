# %%
import pandas as pd

# %%
movies = pd.read_csv('movies.csv')

# %%
ratings = pd.read_csv('ratings.csv')
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
filt = (ratings['rating'] == 0.5)
ratings[filt].count()
# Out:
# userId       1370
# movieId      1370
# rating       1370
# timestamp    1370
# dtype: int64

# %%
movies.iloc[-1]
# Out:
# movieId                                 193609
# title      Andrew Dice Clay: Dice Rules (1991)
# genres                                  Comedy
# Name: 9741, dtype: object

# %%
movies.describe()
# Out:
#              movieId
# count    9742.000000
# mean    42200.353623
# std     52160.494854
# min         1.000000
# 25%      3248.250000
# 50%      7300.000000
# 75%     76232.000000
# max    193609.000000

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
p = set(movies['genres'])

# %%
p
# Out:
# {'(no genres listed)',
#  'Action',
#  'Action|Adventure',
#  'Action|Adventure|Animation',
#  'Action|Adventure|Animation|Children',
#  'Action|Adventure|Animation|Children|Comedy',
#  'Action|Adventure|Animation|Children|Comedy|Fantasy',
#  'Action|Adventure|Animation|Children|Comedy|IMAX',
#  'Action|Adventure|Animation|Children|Comedy|Romance',
#  'Action|Adventure|Animation|Children|Comedy|Sci-Fi',
#  'Action|Adventure|Animation|Children|Comedy|Sci-Fi|IMAX',
#  'Action|Adventure|Animation|Children|Comedy|Western',
#  'Action|Adventure|Animation|Children|Fantasy',
#  'Action|Adventure|Animation|Children|Fantasy|Sci-Fi',
#  'Action|Adventure|Animation|Children|Sci-Fi',
#  'Action|Adventure|Animation|Comedy',
#  'Action|Adventure|Animation|Comedy|Crime|Mystery',
#  'Action|Adventure|Animation|Comedy|Fantasy|Mystery|Sci-Fi',
#  'Action|Adventure|Animation|Comedy|Fantasy|Sci-Fi',
#  'Action|Adventure|Animation|Comedy|Sci-Fi',
#  'Action|Adventure|Animation|Comedy|Thriller',
# ...

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
movies['movieId']
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 9737    193581
# 9738    193583
# 9739    193585
# 9740    193587
# 9741    193609
# Name: movieId, Length: 9742, dtype: int64

# %%
joined = ratings.merge(movies, on='movieId', how='left')
joined.head(10)
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
# 5       1       70     3.0  964982400   From Dusk Till Dawn (1996)
# 6       1      101     5.0  964980868         Bottle Rocket (1996)
# 7       1      110     4.0  964982176            Braveheart (1995)
# 8       1      151     5.0  964984041               Rob Roy (1995)
# 9       1      157     5.0  964984100        Canadian Bacon (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# ...

# %%
len(ratings) == len(joined)
# Out:
# True

# %%
import pandas as pd
ratings_txt = pd.read_csv('ratings_example.txt', sep = '\t')
ratings_txt.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144

# %%
movies_txt = pd.read_csv('movies_example.txt', sep = '\t')
movies_txt.head()
# Out:
#    movieId                                      title                   genres
# 0       31                    Dangerous Minds (1995)                     Drama
# 1       32  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller
# 2       31                    Dangerous Minds (1995)                     Drama

# %%
ratings_txt.merge(movies_txt, on = 'movieId', how = 'outer')
# Out:
#    userId  movieId  rating     timestamp  \
# 0     1.0       31     2.5  1.260759e+09
# 1     1.0       31     2.5  1.260759e+09
# 2     NaN       32     NaN           NaN
#
#                                        title                   genres
# 0                    Dangerous Minds (1995)                     Drama
# 1                    Dangerous Minds (1995)                     Drama
# 2  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller

# %%
ratings_txt.merge(movies_txt, how = 'left', on = 'movieId')
# Out:
#    userId  movieId  rating   timestamp                    title genres
# 0       1       31     2.5  1260759144  Dangerous Minds (1995)   Drama
# 1       1       31     2.5  1260759144  Dangerous Minds (1995)   Drama

# %%
movies_txt.drop_duplicates(subset = 'movieId', keep = 'first', inplace = True)
movies_txt.head()
# Out:
#    movieId                                      title                   genres
# 0       31                    Dangerous Minds (1995)                     Drama
# 1       32  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller

# %%
ratings_txt.merge(movies_txt, how = 'left', on = 'movieId')
# Out:
#    userId  movieId  rating   timestamp                    title genres
# 0       1       31     2.5  1260759144  Dangerous Minds (1995)   Drama

# %%
items_dict = {

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394], 

    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],

    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]

}

purchase_log = {

    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132], 

    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]

}

# %%
# item_id — идентификатор модели (по этому столбцу будем объединять датафреймы)
# vendor — производитель модели
# stock_count — имеющееся на складе количество данных моделей (в штуках)
# purchase_id — идентификатор покупки
# price — стоимость модели в покупке

# %%
items_df = pd.DataFrame(items_dict)
purchase_df = pd.DataFrame(purchase_log)

# %%
items_df
# Out:
#    item_id   vendor  stock_count
# 0   417283  Samsung           54
# 1   849734       LG           33
# 2   132223    Apple          122
# 3   573943    Apple           18
# 4    19475       LG          102
# 5  3294095    Apple           43
# 6   382043  Samsung           77
# 7   302948  Samsung          143
# 8   100132       LG           60
# 9   312394      ZTE           19

# %%
purchase_df
# Out:
#    purchase_id  item_id  price
# 0          101   417283  13900
# 1          101   849734   5330
# 2          101   132223  38200
# 3          112   573943  49990
# 4          121    19475   9890
# 5          145  3294095  33000
# 6          145   382043  67500
# 7          145   302948  34500
# 8          145   103845  89900
# 9          221   100132  11400

# %%
# Объедините получившиеся датафреймы по столбцу item_id с типом outer.

#Определите, модель с каким item_id есть в статистике продаж purchase_df, 
#но не учтена на складе (подсказка: подумайте, какой датафрейм должен быть 
#"левым", а какой "правым", чтобы получить необходимые данные). Введите ответ в виде целого числа.

# %%
#ratings_txt.merge(movies_txt, how = 'left', on = 'movieId')

# items_df = pd.DataFrame(items_dict)
# purchase_df = pd.DataFrame(purchase_log)

sales = items_df.merge(purchase_df, how = 'left', on = 'item_id')

# %%
sales
# Out:
#    item_id   vendor  stock_count  purchase_id    price
# 0   417283  Samsung           54        101.0  13900.0
# 1   849734       LG           33        101.0   5330.0
# 2   132223    Apple          122        101.0  38200.0
# 3   573943    Apple           18        112.0  49990.0
# 4    19475       LG          102        121.0   9890.0
# 5  3294095    Apple           43        145.0  33000.0
# 6   382043  Samsung           77        145.0  67500.0
# 7   302948  Samsung          143        145.0  34500.0
# 8   100132       LG           60        221.0  11400.0
# 9   312394      ZTE           19          NaN      NaN

# %%
merged_goods = items_df.merge(purchase_df, how='outer', on='item_id', indicator=True)
display(merged_goods)
display('отсутствует в статистике продаж purchase_df',merged_goods.item_id[merged_goods.isna().price & merged_goods.isna().purchase_id])
display('отсутствует в базе склада items_df',merged_goods.item_id[merged_goods.isna().vendor & merged_goods.isna().stock_count])
# Out:
#     item_id   vendor  stock_count  purchase_id    price      _merge
# 0    417283  Samsung         54.0        101.0  13900.0        both
# 1    849734       LG         33.0        101.0   5330.0        both
# 2    132223    Apple        122.0        101.0  38200.0        both
# 3    573943    Apple         18.0        112.0  49990.0        both
# 4     19475       LG        102.0        121.0   9890.0        both
# 5   3294095    Apple         43.0        145.0  33000.0        both
# 6    382043  Samsung         77.0        145.0  67500.0        both
# 7    302948  Samsung        143.0        145.0  34500.0        both
# 8    100132       LG         60.0        221.0  11400.0        both
# 9    312394      ZTE         19.0          NaN      NaN   left_only
# 10   103845      NaN          NaN        145.0  89900.0  right_only
# 'отсутствует в статистике продаж purchase_df'
# 9    312394
# Name: item_id, dtype: int64
# 'отсутствует в базе склада items_df'
# 10    103845
# ...

# %%
merged_goods[merged_goods.price.isna()].item_id
merged_goods[merged_goods.stock_count.isna()].item_id
# Out:
# 10    103845
# Name: item_id, dtype: int64

# %%
items_df.shape
# Out:
# (10, 3)

# %%
items_df.vendor.nunique()
# Out:
# 4

# %%
#test = pd.merge(items_df, purchase_df)
test2 = pd.merge(ratings, movies, how = 'outer')
filt = (test2['movieId'] == 3456)
test2[filt]
# Out:
#         userId  movieId  rating  timestamp  \
# 100839     NaN     3456     NaN        NaN
#
#                                                title genres
# 100839  Color of Paradise, The (Rang-e khoda) (1999)  Drama

# %%
#test 3456
# Out:
#    item_id   vendor  stock_count  purchase_id  price
# 0   417283  Samsung           54          101  13900
# 1   849734       LG           33          101   5330
# 2   132223    Apple          122          101  38200
# 3   573943    Apple           18          112  49990
# 4    19475       LG          102          121   9890
# 5  3294095    Apple           43          145  33000
# 6   382043  Samsung           77          145  67500
# 7   302948  Samsung          143          145  34500
# 8   100132       LG           60          221  11400

# %%
items_df
# Out:
#    item_id   vendor  stock_count
# 0   417283  Samsung           54
# 1   849734       LG           33
# 2   132223    Apple          122
# 3   573943    Apple           18
# 4    19475       LG          102
# 5  3294095    Apple           43
# 6   382043  Samsung           77
# 7   302948  Samsung          143
# 8   100132       LG           60
# 9   312394      ZTE           19

# %%
purchase_df
# Out:
#    purchase_id  item_id  price
# 0          101   417283  13900
# 1          101   849734   5330
# 2          101   132223  38200
# 3          112   573943  49990
# 4          121    19475   9890
# 5          145  3294095  33000
# 6          145   382043  67500
# 7          145   302948  34500
# 8          145   103845  89900
# 9          221   100132  11400

# %%
test_2 = pd.merge(purchase_df, items_df)

# %%
test_2
# Out:
#    purchase_id  item_id  price   vendor  stock_count
# 0          101   417283  13900  Samsung           54
# 1          101   849734   5330       LG           33
# 2          101   132223  38200    Apple          122
# 3          112   573943  49990    Apple           18
# 4          121    19475   9890       LG          102
# 5          145  3294095  33000    Apple           43
# 6          145   382043  67500  Samsung           77
# 7          145   302948  34500  Samsung          143
# 8          221   100132  11400       LG           60

# %%
merged_table = items_df.merge(purchase_df, how='outer')

# %%
merged_table
# Out:
#     item_id   vendor  stock_count  purchase_id    price
# 0    417283  Samsung         54.0        101.0  13900.0
# 1    849734       LG         33.0        101.0   5330.0
# 2    132223    Apple        122.0        101.0  38200.0
# 3    573943    Apple         18.0        112.0  49990.0
# 4     19475       LG        102.0        121.0   9890.0
# 5   3294095    Apple         43.0        145.0  33000.0
# 6    382043  Samsung         77.0        145.0  67500.0
# 7    302948  Samsung        143.0        145.0  34500.0
# 8    100132       LG         60.0        221.0  11400.0
# 9    312394      ZTE         19.0          NaN      NaN
# 10   103845      NaN          NaN        145.0  89900.0

# %%
merged_table['new'] = merged_table['stock_count'] * merged_table['price']

# %%
merged_table['new'].max()
# Out:
# 5197500.0

# %%
merged_table
# Out:
#     item_id   vendor  stock_count  purchase_id    price        new
# 0    417283  Samsung         54.0        101.0  13900.0   750600.0
# 1    849734       LG         33.0        101.0   5330.0   175890.0
# 2    132223    Apple        122.0        101.0  38200.0  4660400.0
# 3    573943    Apple         18.0        112.0  49990.0   899820.0
# 4     19475       LG        102.0        121.0   9890.0  1008780.0
# 5   3294095    Apple         43.0        145.0  33000.0  1419000.0
# 6    382043  Samsung         77.0        145.0  67500.0  5197500.0
# 7    302948  Samsung        143.0        145.0  34500.0  4933500.0
# 8    100132       LG         60.0        221.0  11400.0   684000.0
# 9    312394      ZTE         19.0          NaN      NaN        NaN
# 10   103845      NaN          NaN        145.0  89900.0        NaN

# %%
filt = merged_table[merged_table['new']==merged_table['new'].max()]

# %%
filt
# Out:
#    item_id   vendor  stock_count  purchase_id    price        new
# 6   382043  Samsung         77.0        145.0  67500.0  5197500.0

# %%
merged_table['new'].sum()
# Out:
# 19729490.0

# %%
import os

# %%
files = os.listdir('data')
files
# Out:
# ['ratings_1.txt',
#  'ratings_10.txt',
#  'ratings_2.txt',
#  'ratings_3.txt',
#  'ratings_4.txt',
#  'ratings_5.txt',
#  'ratings_6.txt',
#  'ratings_7.txt',
#  'ratings_8.txt',
#  'ratings_9.txt']

# %%
for root, dirs, files in os.walk('data'):
    print(root, dirs, files)
# Out:
# data [] ['ratings_1.txt', 'ratings_10.txt', 'ratings_2.txt', 'ratings_3.txt', 'ratings_4.txt', 'ratings_5.txt', 'ratings_6.txt', 'ratings_7.txt', 'ratings_8.txt', 'ratings_9.txt']

# %%
import os
import pandas as pd
files = os.listdir('data') # склеим файлы в один DF
data = pd.DataFrame(columns = ['userId', 'movieId', 'rating', 'timestamp']) #назначим столбцы
# Для каждого имени файла filename будем записывать его содержимое в датафрейм temp:
for filename in files:
    temp = pd.read_csv(os.path.join('data', filename), names = ['userId', 'movieId', 'rating', 'timestamp'])
#     # И «прибавлять» содержимое очередного файла к data:
    data = pd.concat([data, temp])
data
# Out:
#      userId movieId  rating   timestamp
# 0         1      31     2.5  1260759144
# 1         1    1029     3.0  1260759179
# 2         1    1061     3.0  1260759182
# 3         1    1129     2.0  1260759185
# 4         1    1172     4.0  1260759205
# ...     ...     ...     ...         ...
# 9995    597    2572     3.0   940707828
# 9996    597    2613     3.0   940707355
# 9997    597    2657     4.0   940707124
# 9998    597    2661     4.0   940707609
# 9999    597    2662     3.0   940707473
#
# [100004 rows x 4 columns]
