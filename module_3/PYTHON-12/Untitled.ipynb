# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', 50) # показывать больше строк
pd.set_option('display.max_columns', 50) # показывать больше колонок

# %%
log = pd.read_csv('log.csv')

# %%
log
# Out:
#      Запись пользователя № - user_919  [2019-01-01 14:06:51  Unnamed: 2  \
# 0    Запись пользователя № - user_973  [2019-01-01 14:51:16         NaN
# 1    Запись пользователя № - user_903  [2019-01-01 16:31:16         NaN
# 2    Запись пользователя № - user_954  [2019-01-01 17:17:51         NaN
# 3    Запись пользователя № - user_954  [2019-01-01 21:31:18         NaN
# 4    Запись пользователя № - user_917  [2019-01-01 23:34:55    156789.0
# ..                                ...                   ...         ...
# 994  Запись пользователя № - user_984   [2019-04-20 9:59:58      9754.0
# 995                            #error                   NaN     10054.0
# 996                            #error                   NaN     10454.0
# 997                            #error                   NaN      1000.0
# 998                            #error                   NaN     10754.0
#
#      Unnamed: 3
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# ...

# %%
log.head().isna()
# Out:
#    Запись пользователя № - user_919  [2019-01-01 14:06:51  Unnamed: 2  \
# 0                             False                 False        True
# 1                             False                 False        True
# 2                             False                 False        True
# 3                             False                 False        True
# 4                             False                 False       False
#
#    Unnamed: 3
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True

# %%
np.isnan(log)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-e4622f9b78ec> in <module>
# ----> 1 np.isnan(log)
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
log_np = np.read_csv('log.csv')

# %%
from quilt.data.ResidentMario import missingno_data

# %%
collisions = missingno_data.nyc_collision_factors()

# %%
collisions = collisions.replace("nan", np.nan)

# %%
import missingno as msno
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-74f8e347f364> in <module>
# ----> 1 import missingno as msno
#
# ModuleNotFoundError: No module named 'missingno'

# %% [markdown]
# Посчитайте количество пропусков в столбце time. Метод isna() есть не только у DataFrame, но и у Series. Это значит, что применять его можно не только ко всей таблице, но и к каждому столбцу отдельно.

# %%
log.columns

# %%
log = log.rename(columns = {'[2019-01-01 14:06:51':'time', 'Запись пользователя № - user_919':'user_id'})

# %%
log

# %%
log.isna()

# %%
log['time'].isna().sum()

# %%
log.dropna(axis=0)

# %%
log['user_id'].drop_duplicates()

# %%
log['time'].drop_duplicates()

# %%
log['time'] = log['time'].str.replace('[', '')

# %%
log

# %%
log['time'] = pd.to_datetime(log['time'])

# %%
log['time']

# %%
max_date = log['time'].max()

# %%
max_date

# %% [markdown]
# # df['DOB1'] = df['DOB'].dt.strftime('%m/%d/%Y')

# %%
max_date = max_date.strftime('%Y-%m-%d')

# %%
max_date

# %%
year_column = log['time'].apply(lambda x: x.year)

# %%
year_column

# %%
year_column = log['time'].dt.year

# %%
year_column

# %% [markdown]
# Библиотека pandas позволяет использовать аксессор dt для упрощения подобной работы:

# %% [markdown]
# Аксессор - это атрибут столбца, который хранит переменные типа Timestamp, то есть переменные, которые были строковым представлением времени, а затем изменены с помощью pd.to_datetime(). Если вы попытаетесь обратиться к dt у столбца, в котором лежит что-то отличное от времени, вы получите ошибку.

# %%
log['time'].dt.minute.max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-3dc4b56a4807> in <module>
# ----> 1 log['time'].dt.minute.max()
#
# ...

# %%
log['time'].dt.minute.value_counts()

# %%
log['time'].dt.month.value_counts(ascending=False)

# %% [markdown]
# Задача:
#     Посчитайте, сколько дней в данных являются выходными (то есть субботой или воскресеньем). Введите ответ в поле ниже.
# Например, 300.

# %%
log[(log['time'].dt.dayofweek == 5.0) | (log['time'].dt.dayofweek == 6.0)].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-8cf289d6546a> in <module>
# ...

# %% [markdown]
# Задача:
#     Используйте оригинальные данные log.csv, столбец time.
#
# Подсказка: можно использовать value_counts(). Кроме этого, потребуется написать функцию, которая преобразует дату во время дня.
#
# Договоримся, что с 0 до 5 часов - ночь, с 6 до 11 - утро, с 12 до 17 - день, с 18 до 23 - вечер.
#
# Важно: для выполнения задания вам нужно будет избавиться от пропусков только в столбце time. Вспомните, как избавиться от пропусков только по конкретному признаку.
#
# Посчитайте, какое время дня встречается в данных реже всего. Введите ответ в поле ниже: ночь, утро, день или вечер.
# Например, ночь.

# %%
log['day_time'] = log['time'].apply(lambda x: x.hour)

# %%
log
# Out:
#      Запись пользователя № - user_919  [2019-01-01 14:06:51  Unnamed: 2  \
# 0    Запись пользователя № - user_973  [2019-01-01 14:51:16         NaN
# 1    Запись пользователя № - user_903  [2019-01-01 16:31:16         NaN
# 2    Запись пользователя № - user_954  [2019-01-01 17:17:51         NaN
# 3    Запись пользователя № - user_954  [2019-01-01 21:31:18         NaN
# 4    Запись пользователя № - user_917  [2019-01-01 23:34:55    156789.0
# ..                                ...                   ...         ...
# 994  Запись пользователя № - user_984   [2019-04-20 9:59:58      9754.0
# 995                            #error                   NaN     10054.0
# 996                            #error                   NaN     10454.0
# 997                            #error                   NaN      1000.0
# 998                            #error                   NaN     10754.0
#
#      Unnamed: 3
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# ...

# %%
(lambda x: 1 if 0.0<=x<=5.0 else(2 if 6.0<=x<=11.0 else(3 if 12.0<=x<=17.0 else 4)))
# Out:
# <function __main__.<lambda>(x)>

# %%
log['day_time'] = log['day_time'].apply(lambda x: 'ночь' if 0.0<=x<=5.0 else('утро' if 6.0<=x<=11.0 else('день' if 12.0<=x<=17.0 else('вечер' if 18.0<=x<=23.0 else 'NaN'))))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'day_time'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-c7ec7b01f020> in <module>
# ...

# %%
log

# %%
log['day_time'].value_counts()

# %%
log
# Out:
#      Запись пользователя № - user_919  [2019-01-01 14:06:51  Unnamed: 2  \
# 0    Запись пользователя № - user_973  [2019-01-01 14:51:16         NaN
# 1    Запись пользователя № - user_903  [2019-01-01 16:31:16         NaN
# 2    Запись пользователя № - user_954  [2019-01-01 17:17:51         NaN
# 3    Запись пользователя № - user_954  [2019-01-01 21:31:18         NaN
# 4    Запись пользователя № - user_917  [2019-01-01 23:34:55    156789.0
# ..                                ...                   ...         ...
# 994  Запись пользователя № - user_984   [2019-04-20 9:59:58      9754.0
# 995                            #error                   NaN     10054.0
# 996                            #error                   NaN     10454.0
# 997                            #error                   NaN      1000.0
# 998                            #error                   NaN     10754.0
#
#      Unnamed: 3
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# ...

# %%
del log['day_time']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'day_time'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-29bad18dfaef> in <module>
# ----> 1 del log['day_time']
#
# ...

# %%
log

# %%
log = log.rename(columns = {'Unnamed: 2':'bet', 'Unnamed: 3':'win'})

# %%
log

# %%
log.isna()
# Out:
#      Запись пользователя № - user_919  [2019-01-01 14:06:51  Unnamed: 2  \
# 0                               False                 False        True
# 1                               False                 False        True
# 2                               False                 False        True
# 3                               False                 False        True
# 4                               False                 False       False
# ..                                ...                   ...         ...
# 994                             False                 False       False
# 995                             False                  True       False
# 996                             False                  True       False
# 997                             False                  True       False
# 998                             False                  True       False
#
#      Unnamed: 3
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
log = log.dropna(axis=0)

# %%
log
# Out:
#      Запись пользователя № - user_919  [2019-01-01 14:06:51  Unnamed: 2  \
# 13   Запись пользователя № - user_917   [2019-01-02 8:57:36    145732.0
# 28   Запись пользователя № - user_942  [2019-01-04 13:59:42   1678321.0
# 150  Запись пользователя № - user_982  [2019-01-16 21:54:22       100.0
# 188  Запись пользователя № - user_964  [2019-01-21 18:34:44       200.0
# 204  Запись пользователя № - user_931   [2019-01-22 5:26:59       300.0
# ..                                ...                   ...         ...
# 966  Запись пользователя № - user_975  [2019-04-19 22:25:15      1000.0
# 970  Запись пользователя № - user_912  [2019-04-20 10:35:49     10554.0
# 971  Запись пользователя № - user_926  [2019-04-20 10:35:50     10354.0
# 975  Запись пользователя № - user_970  [2019-04-20 10:35:54     10354.0
# 990  Запись пользователя № - user_965  [2019-04-20 12:55:41       800.0
#
#      Unnamed: 3
# 13    1987653.0
# 28    9876543.0
# 150      4749.0
# 188      4667.0
# ...

# %%
log['time'] = pd.to_datetime(log['time'])
log
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-21451af1208c> in <module>
# ----> 1 log['time'] = pd.to_datetime(log['time'])
# ...

# %%
log['time']

# %%
log['hour'] = log['time'].dt.hour
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-481ff9c46af5> in <module>
# ----> 1 log['hour'] = log['time'].dt.hour
#
# ...

# %%
log

# %%
# ваш код здесь
import pandas as pd
log = pd.read_csv('log.csv')

log = log.rename(columns = {'[2019-01-01 14:06:51':'time', 'Запись пользователя № - user_919':'user_id', 'Unnamed: 2':'bet', 'Unnamed: 3':'win'})
log.isna()
log = log.dropna(axis=0)
log['time'] = pd.to_datetime(log['time'])
log['hour'] = log['time'].dt.hour

# %% [markdown]
# Используйте оригинальный датасет log.csv. Результат запишите числом в поле ниже.
#
# Подсказка: можно использовать value_counts().
#
# Посчитайте, сколько раз люди приходили, но не делали ставок. Для этого заполните пропуски в столбце bet значением 0 и посчитайте количество таких значений.
# Например, 66.

# %%
log
# Out:
#      Запись пользователя № - user_919  [2019-01-01 14:06:51  Unnamed: 2  \
# 13   Запись пользователя № - user_917   [2019-01-02 8:57:36    145732.0
# 28   Запись пользователя № - user_942  [2019-01-04 13:59:42   1678321.0
# 150  Запись пользователя № - user_982  [2019-01-16 21:54:22       100.0
# 188  Запись пользователя № - user_964  [2019-01-21 18:34:44       200.0
# 204  Запись пользователя № - user_931   [2019-01-22 5:26:59       300.0
# ..                                ...                   ...         ...
# 966  Запись пользователя № - user_975  [2019-04-19 22:25:15      1000.0
# 970  Запись пользователя № - user_912  [2019-04-20 10:35:49     10554.0
# 971  Запись пользователя № - user_926  [2019-04-20 10:35:50     10354.0
# 975  Запись пользователя № - user_970  [2019-04-20 10:35:54     10354.0
# 990  Запись пользователя № - user_965  [2019-04-20 12:55:41       800.0
#
#      Unnamed: 3
# 13    1987653.0
# 28    9876543.0
# 150      4749.0
# 188      4667.0
# ...

# %%
log = pd.read_csv('log.csv')

# %%
log
# Out:
#      Запись пользователя № - user_919  [2019-01-01 14:06:51  Unnamed: 2  \
# 0    Запись пользователя № - user_973  [2019-01-01 14:51:16         NaN
# 1    Запись пользователя № - user_903  [2019-01-01 16:31:16         NaN
# 2    Запись пользователя № - user_954  [2019-01-01 17:17:51         NaN
# 3    Запись пользователя № - user_954  [2019-01-01 21:31:18         NaN
# 4    Запись пользователя № - user_917  [2019-01-01 23:34:55    156789.0
# ..                                ...                   ...         ...
# 994  Запись пользователя № - user_984   [2019-04-20 9:59:58      9754.0
# 995                            #error                   NaN     10054.0
# 996                            #error                   NaN     10454.0
# 997                            #error                   NaN      1000.0
# 998                            #error                   NaN     10754.0
#
#      Unnamed: 3
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# ...

# %%
log = log.rename(columns = {'[2019-01-01 14:06:51':'time', 'Запись пользователя № - user_919':'user_id', 'Unnamed: 2':'bet', 'Unnamed: 3':'win'})

# %%
log
# Out:
#                               user_id                  time       bet      win
# 0    Запись пользователя № - user_973  [2019-01-01 14:51:16       NaN      NaN
# 1    Запись пользователя № - user_903  [2019-01-01 16:31:16       NaN      NaN
# 2    Запись пользователя № - user_954  [2019-01-01 17:17:51       NaN      NaN
# 3    Запись пользователя № - user_954  [2019-01-01 21:31:18       NaN      NaN
# 4    Запись пользователя № - user_917  [2019-01-01 23:34:55  156789.0      NaN
# ..                                ...                   ...       ...      ...
# 994  Запись пользователя № - user_984   [2019-04-20 9:59:58    9754.0      NaN
# 995                            #error                   NaN   10054.0  29265.0
# 996                            #error                   NaN   10454.0      NaN
# 997                            #error                   NaN    1000.0      NaN
# 998                            #error                   NaN   10754.0      NaN
#
# [999 rows x 4 columns]

# %%
log['bet'] = log['bet'].fillna(0)

# %%
log['bet'].value_counts()
# Out:
# 0.0          514
# 500.0         50
# 100.0         48
# 300.0         42
# 800.0         42
# 200.0         40
# 400.0         40
# 700.0         38
# 600.0         37
# 1000.0        37
# 900.0         30
# 9754.0        10
# 10554.0       10
# 10154.0        7
# 10254.0        7
# 10454.0        6
# 9954.0         6
# 10754.0        5
# 10654.0        5
# 10354.0        4
# 10054.0        4
# 9854.0         2
# 5000.0         1
# 27000.0        1
# 9876.0         1
# 156789.0       1
# 12945.0        1
# 12548.0        1
# 145732.0       1
# 1678321.0      1
# 98753.0        1
# 123981.0       1
# 104540.0       1
# 8700.0         1
# 950.0          1
# 8734.0         1
# 7650.0         1
# Name: bet, dtype: int64

# %%
def fillna_win(row):  
    # Нужно дописать  
    log['bet'].fillna(0, inplace = True)
    
    
    
    
# Применяем функцию  
new_win = log.apply(lambda row: fillna_win(row), axis=1)  
  
# Заменяем старый столбец с пропусками на новый без пропусков  
log['win'] = new_win['win']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-dffaf8b74eb2> in <module>
#      10
#      11 # Заменяем старый столбец с пропусками на новый без пропусков
# ---> 12 log['win'] = new_win['win']
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
# ...

# %% [markdown]
# Если значение в столбце win существует (не пропуск) - вернуть это же значение. Это значит, что человек выиграл.
#
# Если вместо значения в столбце win и в столбце bet пропуски, вернуть 0.
#
# Если в столбце bet нет пропуска, а в столбце win есть пропуск, вернуть отрицательное значение столбца bet (проигрыш).

# %%
log

# %%
log['bet'].value_counts()

# %%
log['win'].fillna(0, inplace = True)

# %%
log

# %%
log[(log['bet'] != 0.0) & (log['win'] == 0.0)]
# Out:
# Empty DataFrame
# Columns: [user_id, time, bet, win]
# Index: []

# %% [markdown]
# Используйте модифицированный в прошлой секции датасет log.csv. Результат запишите числом в поле ниже.
#
# Подсказка: можно использовать sum().
# Создайте признак net, хранящий сумму выигрыша с учетом ставки. Для этого используйте следующий алгоритм:
# - если значение признака win меньше 0 - присвоить значение признака win признаку net;
#
# - во всех остальных случаях - из значения признака win вычтите значение признака bet и полученное значение присвойте признаку net.
#
# После этого посчитайте, у скольких людей выигрыш положительный.
# Например, 0.

# %%
log['net'] = log[(log['win'] == 0)].apply(lambda x: 'test')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-3729818c24e3> in <module>
# ----> 1 log['net'] = log[(log['win'] == 0)].apply(lambda x: 'test')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178         # one axis empty
#     179         elif not all(self.obj.shape):
# --> 180             return self.apply_empty_result()
#     181
#     182         # raw
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_empty_result(self)
#     214
#     215         if reduce:
# ...

# %%
log['net'] = log['win'].apply(lambda x: 0 if x == 0 else(log['win']-log['bet']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'net'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
# ...

# %%
frame[['b','c']].apply(lambda x: x['c'] if x['c']>0 else x['b'], axis=1)

# %%
def new_1(win, bet):
    if win < 0:
        return win
    else:
        return win - bet

# %%
log['net'] = log.apply(lambda x: new_1(x['win'],x['bet']), axis=1)

# %%
log

# %%
log['test'] = log['net'].apply(lambda x: x if x>0 else('Nan'))

# %%
log

# %%
log['net'].apply(lambda x: x>0).value_counts()

# %%
log['net'].apply(lambda x: x>0).sum()

# %%
(log['net'] > 0).sum()

# %%
log['net'].loc[log['net']>0].sum()

# %%
log['net'].loc[log['net']>0].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'net'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-b7362dfc204c> in <module>
# ----> 1 log['net'].loc[log['net']>0].mean()
#
# ...

# %%
log['net'].loc[log['net']>0].median()

# %% [markdown]
# Посчитайте, какой процент посещений букмекерской конторы оборачивался ставкой.
#
# Для этого поделите количество ставок (значений больше 0) на общее количество посещений конторы. Результат округлите до одного знака после запятой.

# %%
log

# %%
(log['bet'] > 0).sum()
# Out:
# 485

# %%
log['bet'].count()
# Out:
# 999

# %%
(log['bet'] > 0).sum() / log['bet'].count()
# Out:
# 0.4854854854854855

# %% [markdown]
# Задание 2
#
# Используйте датасет log.csv, получившийся в результате модификации при выполнении первого задания этого блока.
#
# Посчитайте среднее значение ставки (из столбца bet) в тех случаях, когда ставка была сделана. Запишите результат, отбросив дробную часть.
# Подсказка: можно использовать mean().

# %%
log['bet'].loc[log['bet']>0].mean()
# Out:
# 6785.738144329897

# %%
log['net'].loc[log['net']>0].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'net'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-b7362dfc204c> in <module>
# ----> 1 log['net'].loc[log['net']>0].mean()
#
# ...

# %%
log['net'].mean()

# %%
log['net'].loc[log['net']<0].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'net'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-ae2db928636d> in <module>
# ----> 1 log['net'].loc[log['net']<0].mean()
#
# ...

# %% [markdown]
# Посчитайте, какой процент ставок заканчивается выигрышем, а какой - проигрышем. Сравните эти значения и ответьте, какое из них больше.

# %%
log['bet'].loc[log['bet']>0].count()

# %%
log['win'].loc[log['win']>0].count()

# %%
(log['win'].loc[log['win']>0].count()) / (log['bet'].loc[log['bet']>0].count()) * 100
# Out:
# 28.45360824742268

# %% [markdown]
# Давайте повторим то, что мы прошли в этой секции. Напишите код, который узнает, чему была равна минимальная ставка и сколько людей сделали такую ставку. Для этого:
#
# 1. загрузите датасет log.csv;
#
# 2. посчитайте, чему равна минимальная ставка;
#
# 3. посчитайте, сколько раз была сделана минимальная ставка, и запишите результат в переменную min_bet_amount в виде целого числа.

# %%
log['bet'][log['bet']==(log['bet'].loc[log['bet']>0].min())].count()
# Out:
# 48

# %%
log['bet'].loc[log['bet']>0].value_counts().min()
# Out:
# 1

# %%
log['bet'].value_counts()
# Out:
# 0.0          514
# 500.0         50
# 100.0         48
# 300.0         42
# 800.0         42
# 200.0         40
# 400.0         40
# 700.0         38
# 600.0         37
# 1000.0        37
# 900.0         30
# 9754.0        10
# 10554.0       10
# 10154.0        7
# 10254.0        7
# 10454.0        6
# 9954.0         6
# 10754.0        5
# 10654.0        5
# 10354.0        4
# 10054.0        4
# 9854.0         2
# 5000.0         1
# 27000.0        1
# 9876.0         1
# 156789.0       1
# 12945.0        1
# 12548.0        1
# 145732.0       1
# 1678321.0      1
# 98753.0        1
# 123981.0       1
# 104540.0       1
# 8700.0         1
# 950.0          1
# 8734.0         1
# 7650.0         1
# Name: bet, dtype: int64

# %%
import pandas as pd
log = pd.read_csv("log.csv", header=None)
log.columns = ['user_id', 'time', 'bet', 'win']


min_bet_amount = log['bet'][log['bet']==(log['bet'].loc[log['bet']>0].min())].count()
print(min_bet_amount)
log
# Out:
# 48
#                               user_id                  time      bet      win
# 0    Запись пользователя № - user_919  [2019-01-01 14:06:51      NaN      NaN
# 1    Запись пользователя № - user_973  [2019-01-01 14:51:16      NaN      NaN
# 2    Запись пользователя № - user_903  [2019-01-01 16:31:16      NaN      NaN
# 3    Запись пользователя № - user_954  [2019-01-01 17:17:51      NaN      NaN
# 4    Запись пользователя № - user_954  [2019-01-01 21:31:18      NaN      NaN
# ..                                ...                   ...      ...      ...
# 995  Запись пользователя № - user_984   [2019-04-20 9:59:58   9754.0      NaN
# 996                            #error                   NaN  10054.0  29265.0
# 997                            #error                   NaN  10454.0      NaN
# 998                            #error                   NaN   1000.0      NaN
# 999                            #error                   NaN  10754.0      NaN
#
# [1000 rows x 4 columns]

# %%
us = pd.read_csv('users.csv', engine='python')

# %%
us
# Out:
#                   п»ї"Р°РЄР§Р•РўРЁ\tРќР•РљРњ\tР·Р•Рџ"
# 0         User_943\tAccumanst@gmail.com\tР№Р¦Р•Р§РЈР›
# 1           User_908\tAdvismowr@mail.ru\tР№Р¦Р•Р§РЈР›
# 2       User_962\tAnachso@ukr.net\tР»РўР‘РЈРћРџР”Р‘Рў
# 3              User_973\tAntecia@inbox.ru\tСЂР•РўРќРЁ
# 4                      User_902\tBalliaryva@ukr.net\t
# ..                                                ...
# 95   User_959\tUpdatesCurious@yahoo.com\tС„РђРќР•РћРЁ
# 96  User_901\tV2artierso@mail.ru\tР±РўРЄР‘РћР—Р•Рњ...
# 97         User_970\tVashoterlo@bk.ru\tС‡РџРўРџРћР•Р¦
# 98      User_965\tVisuareda@yahoo.com\tС‡РџРўРџРћР•Р¦
# 99               User_921\tAavast@ya.ru\tР№Р¦Р•Р§РЈР›
#
# [100 rows x 1 columns]

# %%
us = pd.read_csv('users_1.csv', encoding='KOI8-R', sep='\t')

# %%
us
# Out:
#                              Юзверь;мейл;Гео
# 0        User_943;Accumanst@gmail.com;Ижевск
# 1          User_908;Advismowr@mail.ru;Ижевск
# 2         User_962;Anachso@ukr.net;Краснодар
# 3            User_973;Antecia@inbox.ru;Пермь
# 4               User_902;Balliaryva@ukr.net;
# ..                                       ...
# 95  User_959;UpdatesCurious@yahoo.com;Тюмень
# 96   User_901;V2artierso@mail.ru;Арзангелтск
# 97         User_970;Vashoterlo@bk.ru;Воронеж
# 98      User_965;Visuareda@yahoo.com;Воронеж
# 99              User_921;Aavast@ya.ru;Ижевск
#
# [100 rows x 1 columns]

# %%
us = pd.read_csv('users_1.csv', encoding='KOI8-R', sep=';')
us.columns = ['user_id', 'email', 'geo']

# %%
us
# Out:
#      user_id                     email          geo
# 0   User_943       Accumanst@gmail.com       Ижевск
# 1   User_908         Advismowr@mail.ru       Ижевск
# 2   User_962           Anachso@ukr.net    Краснодар
# 3   User_973          Antecia@inbox.ru        Пермь
# 4   User_902        Balliaryva@ukr.net          NaN
# ..       ...                       ...          ...
# 95  User_959  UpdatesCurious@yahoo.com       Тюмень
# 96  User_901        V2artierso@mail.ru  Арзангелтск
# 97  User_970          Vashoterlo@bk.ru      Воронеж
# 98  User_965       Visuareda@yahoo.com      Воронеж
# 99  User_921              Aavast@ya.ru       Ижевск
#
# [100 rows x 3 columns]

# %%
us.user_id = us.user_id.apply(lambda x: x.lower())

# %%
us
# Out:
#      user_id                     email          geo
# 0   user_943       Accumanst@gmail.com       Ижевск
# 1   user_908         Advismowr@mail.ru       Ижевск
# 2   user_962           Anachso@ukr.net    Краснодар
# 3   user_973          Antecia@inbox.ru        Пермь
# 4   user_902        Balliaryva@ukr.net          NaN
# ..       ...                       ...          ...
# 95  user_959  UpdatesCurious@yahoo.com       Тюмень
# 96  user_901        V2artierso@mail.ru  Арзангелтск
# 97  user_970          Vashoterlo@bk.ru      Воронеж
# 98  user_965       Visuareda@yahoo.com      Воронеж
# 99  user_921              Aavast@ya.ru       Ижевск
#
# [100 rows x 3 columns]

# %%
log
# Out:
#                               user_id                  time      bet      win
# 0    Запись пользователя № - user_919  [2019-01-01 14:06:51      NaN      NaN
# 1    Запись пользователя № - user_973  [2019-01-01 14:51:16      NaN      NaN
# 2    Запись пользователя № - user_903  [2019-01-01 16:31:16      NaN      NaN
# 3    Запись пользователя № - user_954  [2019-01-01 17:17:51      NaN      NaN
# 4    Запись пользователя № - user_954  [2019-01-01 21:31:18      NaN      NaN
# ..                                ...                   ...      ...      ...
# 995  Запись пользователя № - user_984   [2019-04-20 9:59:58   9754.0      NaN
# 996                            #error                   NaN  10054.0  29265.0
# 997                            #error                   NaN  10454.0      NaN
# 998                            #error                   NaN   1000.0      NaN
# 999                            #error                   NaN  10754.0      NaN
#
# [1000 rows x 4 columns]

# %%
log = log[log.user_id != '#error']

# %%
log
# Out:
#                               user_id                  time      bet     win
# 0    Запись пользователя № - user_919  [2019-01-01 14:06:51      NaN     NaN
# 1    Запись пользователя № - user_973  [2019-01-01 14:51:16      NaN     NaN
# 2    Запись пользователя № - user_903  [2019-01-01 16:31:16      NaN     NaN
# 3    Запись пользователя № - user_954  [2019-01-01 17:17:51      NaN     NaN
# 4    Запись пользователя № - user_954  [2019-01-01 21:31:18      NaN     NaN
# ..                                ...                   ...      ...     ...
# 991  Запись пользователя № - user_965  [2019-04-20 12:55:41    800.0  6927.0
# 992  Запись пользователя № - user_967  [2019-04-20 14:59:36  10154.0     NaN
# 993  Запись пользователя № - user_973  [2019-04-20 17:09:56  10254.0     NaN
# 994  Запись пользователя № - user_977  [2019-04-20 18:10:07  10354.0     NaN
# 995  Запись пользователя № - user_984   [2019-04-20 9:59:58   9754.0     NaN
#
# [985 rows x 4 columns]

# %%
log.user_id = log.user_id.str.split(' - ').apply(lambda x: x[1])  
log
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#       user_id                  time      bet     win
# 0    user_919  [2019-01-01 14:06:51      NaN     NaN
# 1    user_973  [2019-01-01 14:51:16      NaN     NaN
# 2    user_903  [2019-01-01 16:31:16      NaN     NaN
# 3    user_954  [2019-01-01 17:17:51      NaN     NaN
# 4    user_954  [2019-01-01 21:31:18      NaN     NaN
# ..        ...                   ...      ...     ...
# 991  user_965  [2019-04-20 12:55:41    800.0  6927.0
# 992  user_967  [2019-04-20 14:59:36  10154.0     NaN
# 993  user_973  [2019-04-20 17:09:56  10254.0     NaN
# 994  user_977  [2019-04-20 18:10:07  10354.0     NaN
# ...

# %%
log['time'] = log['time'].str.replace('[','')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
log
# Out:
#       user_id                 time      bet     win
# 0    user_919  2019-01-01 14:06:51      NaN     NaN
# 1    user_973  2019-01-01 14:51:16      NaN     NaN
# 2    user_903  2019-01-01 16:31:16      NaN     NaN
# 3    user_954  2019-01-01 17:17:51      NaN     NaN
# 4    user_954  2019-01-01 21:31:18      NaN     NaN
# ..        ...                  ...      ...     ...
# 991  user_965  2019-04-20 12:55:41    800.0  6927.0
# 992  user_967  2019-04-20 14:59:36  10154.0     NaN
# 993  user_973  2019-04-20 17:09:56  10254.0     NaN
# 994  user_977  2019-04-20 18:10:07  10354.0     NaN
# 995  user_984   2019-04-20 9:59:58   9754.0     NaN
#
# [985 rows x 4 columns]

# %%
table = pd.merge(log, us, on='user_id')
table
# Out:
#       user_id                 time    bet     win                   email  \
# 0    user_919  2019-01-01 14:06:51    NaN     NaN  Chikkaverle@icloud.com
# 1    user_919  2019-01-30 10:06:00    NaN     NaN  Chikkaverle@icloud.com
# 2    user_919  2019-02-05 14:33:44    NaN     NaN  Chikkaverle@icloud.com
# 3    user_919  2019-02-14 11:38:05    NaN     NaN  Chikkaverle@icloud.com
# 4    user_919   2019-03-02 4:23:36  300.0     NaN  Chikkaverle@icloud.com
# ..        ...                  ...    ...     ...                     ...
# 970  user_932  2019-02-24 22:40:06    NaN     NaN       BraceWalker@bk.ru
# 971  user_932  2019-03-15 10:56:14    NaN     NaN       BraceWalker@bk.ru
# 972  user_932  2019-03-18 10:13:24    NaN     NaN       BraceWalker@bk.ru
# 973  user_932  2019-03-27 12:18:24    NaN     NaN       BraceWalker@bk.ru
# 974  user_932  2019-04-18 14:55:26  700.0  6640.0       BraceWalker@bk.ru
#
#             geo
# 0     Хабаровск
# 1     Хабаровск
# 2     Хабаровск
# ...

# %%
table.groupby('user_id').win.median().median()
# Out:
# 5951.75

# %%
table.groupby('user_id').win.median()
# Out:
# user_id
# user_1000    4701.0
# user_900     6202.5
# user_901        NaN
# user_902     4021.0
# user_903     6726.0
#               ...
# user_995     5889.0
# user_996     4056.0
# user_997        NaN
# user_998     6294.0
# user_999        NaN
# Name: win, Length: 100, dtype: float64

# %%
table
# Out:
#       user_id                 time    bet     win                   email  \
# 0    user_919  2019-01-01 14:06:51    NaN     NaN  Chikkaverle@icloud.com
# 1    user_919  2019-01-30 10:06:00    NaN     NaN  Chikkaverle@icloud.com
# 2    user_919  2019-02-05 14:33:44    NaN     NaN  Chikkaverle@icloud.com
# 3    user_919  2019-02-14 11:38:05    NaN     NaN  Chikkaverle@icloud.com
# 4    user_919   2019-03-02 4:23:36  300.0     NaN  Chikkaverle@icloud.com
# ..        ...                  ...    ...     ...                     ...
# 970  user_932  2019-02-24 22:40:06    NaN     NaN       BraceWalker@bk.ru
# 971  user_932  2019-03-15 10:56:14    NaN     NaN       BraceWalker@bk.ru
# 972  user_932  2019-03-18 10:13:24    NaN     NaN       BraceWalker@bk.ru
# 973  user_932  2019-03-27 12:18:24    NaN     NaN       BraceWalker@bk.ru
# 974  user_932  2019-04-18 14:55:26  700.0  6640.0       BraceWalker@bk.ru
#
#             geo
# 0     Хабаровск
# 1     Хабаровск
# 2     Хабаровск
# ...

# %%
table['bet'] = table['bet'].fillna(0)

# %%
table['win'] = table['win'].fillna(0)
table
# Out:
#       user_id                 time    bet     win                   email  \
# 0    user_919  2019-01-01 14:06:51    0.0     0.0  Chikkaverle@icloud.com
# 1    user_919  2019-01-30 10:06:00    0.0     0.0  Chikkaverle@icloud.com
# 2    user_919  2019-02-05 14:33:44    0.0     0.0  Chikkaverle@icloud.com
# 3    user_919  2019-02-14 11:38:05    0.0     0.0  Chikkaverle@icloud.com
# 4    user_919   2019-03-02 4:23:36  300.0     0.0  Chikkaverle@icloud.com
# ..        ...                  ...    ...     ...                     ...
# 970  user_932  2019-02-24 22:40:06    0.0     0.0       BraceWalker@bk.ru
# 971  user_932  2019-03-15 10:56:14    0.0     0.0       BraceWalker@bk.ru
# 972  user_932  2019-03-18 10:13:24    0.0     0.0       BraceWalker@bk.ru
# 973  user_932  2019-03-27 12:18:24    0.0     0.0       BraceWalker@bk.ru
# 974  user_932  2019-04-18 14:55:26  700.0  6640.0       BraceWalker@bk.ru
#
#             geo
# 0     Хабаровск
# 1     Хабаровск
# 2     Хабаровск
# ...

# %%
def new_1(win, bet):
    if win < 0:
        return win
    else:
        return win - bet

# %%
table['net'] = log.apply(lambda x: new_1(x['win'],x['bet']), axis=1)

# %%
table['net'] = table['net'].fillna(0) 
table
# Out:
#       user_id                 time    bet     win                   email  \
# 0    user_919  2019-01-01 14:06:51    0.0     0.0  Chikkaverle@icloud.com
# 1    user_919  2019-01-30 10:06:00    0.0     0.0  Chikkaverle@icloud.com
# 2    user_919  2019-02-05 14:33:44    0.0     0.0  Chikkaverle@icloud.com
# 3    user_919  2019-02-14 11:38:05    0.0     0.0  Chikkaverle@icloud.com
# 4    user_919   2019-03-02 4:23:36  300.0     0.0  Chikkaverle@icloud.com
# ..        ...                  ...    ...     ...                     ...
# 970  user_932  2019-02-24 22:40:06    0.0     0.0       BraceWalker@bk.ru
# 971  user_932  2019-03-15 10:56:14    0.0     0.0       BraceWalker@bk.ru
# 972  user_932  2019-03-18 10:13:24    0.0     0.0       BraceWalker@bk.ru
# 973  user_932  2019-03-27 12:18:24    0.0     0.0       BraceWalker@bk.ru
# 974  user_932  2019-04-18 14:55:26  700.0  6640.0       BraceWalker@bk.ru
#
#             geo      net
# 0     Хабаровск      0.0
# 1     Хабаровск      0.0
# ...

# %%
log = pd.read_csv("log.csv", header=None)
log
# Out:
#                                     0                     1        2        3
# 0    Запись пользователя № - user_919  [2019-01-01 14:06:51      NaN      NaN
# 1    Запись пользователя № - user_973  [2019-01-01 14:51:16      NaN      NaN
# 2    Запись пользователя № - user_903  [2019-01-01 16:31:16      NaN      NaN
# 3    Запись пользователя № - user_954  [2019-01-01 17:17:51      NaN      NaN
# 4    Запись пользователя № - user_954  [2019-01-01 21:31:18      NaN      NaN
# ..                                ...                   ...      ...      ...
# 995  Запись пользователя № - user_984   [2019-04-20 9:59:58   9754.0      NaN
# 996                            #error                   NaN  10054.0  29265.0
# 997                            #error                   NaN  10454.0      NaN
# 998                            #error                   NaN   1000.0      NaN
# 999                            #error                   NaN  10754.0      NaN
#
# [1000 rows x 4 columns]

# %%
log.columns = ['user_id', 'time', 'bet', 'win']
log
# Out:
#                               user_id                  time      bet      win
# 0    Запись пользователя № - user_919  [2019-01-01 14:06:51      NaN      NaN
# 1    Запись пользователя № - user_973  [2019-01-01 14:51:16      NaN      NaN
# 2    Запись пользователя № - user_903  [2019-01-01 16:31:16      NaN      NaN
# 3    Запись пользователя № - user_954  [2019-01-01 17:17:51      NaN      NaN
# 4    Запись пользователя № - user_954  [2019-01-01 21:31:18      NaN      NaN
# ..                                ...                   ...      ...      ...
# 995  Запись пользователя № - user_984   [2019-04-20 9:59:58   9754.0      NaN
# 996                            #error                   NaN  10054.0  29265.0
# 997                            #error                   NaN  10454.0      NaN
# 998                            #error                   NaN   1000.0      NaN
# 999                            #error                   NaN  10754.0      NaN
#
# [1000 rows x 4 columns]

# %%
log['win'] = log['win'].fillna(0)
log['bet'] = log['bet'].fillna(0)
log
# Out:
#                               user_id                  time      bet      win
# 0    Запись пользователя № - user_919  [2019-01-01 14:06:51      0.0      0.0
# 1    Запись пользователя № - user_973  [2019-01-01 14:51:16      0.0      0.0
# 2    Запись пользователя № - user_903  [2019-01-01 16:31:16      0.0      0.0
# 3    Запись пользователя № - user_954  [2019-01-01 17:17:51      0.0      0.0
# 4    Запись пользователя № - user_954  [2019-01-01 21:31:18      0.0      0.0
# ..                                ...                   ...      ...      ...
# 995  Запись пользователя № - user_984   [2019-04-20 9:59:58   9754.0      0.0
# 996                            #error                   NaN  10054.0  29265.0
# 997                            #error                   NaN  10454.0      0.0
# 998                            #error                   NaN   1000.0      0.0
# 999                            #error                   NaN  10754.0      0.0
#
# [1000 rows x 4 columns]

# %%
log['time'] = log['time'].str.replace('[', '')
log
# Out:
#                               user_id                 time      bet      win
# 0    Запись пользователя № - user_919  2019-01-01 14:06:51      0.0      0.0
# 1    Запись пользователя № - user_973  2019-01-01 14:51:16      0.0      0.0
# 2    Запись пользователя № - user_903  2019-01-01 16:31:16      0.0      0.0
# 3    Запись пользователя № - user_954  2019-01-01 17:17:51      0.0      0.0
# 4    Запись пользователя № - user_954  2019-01-01 21:31:18      0.0      0.0
# ..                                ...                  ...      ...      ...
# 995  Запись пользователя № - user_984   2019-04-20 9:59:58   9754.0      0.0
# 996                            #error                  NaN  10054.0  29265.0
# 997                            #error                  NaN  10454.0      0.0
# 998                            #error                  NaN   1000.0      0.0
# 999                            #error                  NaN  10754.0      0.0
#
# [1000 rows x 4 columns]

# %%
log['user_id'] = log[log['user_id'] != '#error']
log
# Out:
#                               user_id                 time      bet      win
# 0    Запись пользователя № - user_919  2019-01-01 14:06:51      0.0      0.0
# 1    Запись пользователя № - user_973  2019-01-01 14:51:16      0.0      0.0
# 2    Запись пользователя № - user_903  2019-01-01 16:31:16      0.0      0.0
# 3    Запись пользователя № - user_954  2019-01-01 17:17:51      0.0      0.0
# 4    Запись пользователя № - user_954  2019-01-01 21:31:18      0.0      0.0
# ..                                ...                  ...      ...      ...
# 995  Запись пользователя № - user_984   2019-04-20 9:59:58   9754.0      0.0
# 996                               NaN                  NaN  10054.0  29265.0
# 997                               NaN                  NaN  10454.0      0.0
# 998                               NaN                  NaN   1000.0      0.0
# 999                               NaN                  NaN  10754.0      0.0
#
# [1000 rows x 4 columns]

# %%
log['user_id'] = log['user_id'].str.replace('Запись пользователя № - ', '')
log
# Out:
#       user_id                 time      bet      win
# 0    user_919  2019-01-01 14:06:51      0.0      0.0
# 1    user_973  2019-01-01 14:51:16      0.0      0.0
# 2    user_903  2019-01-01 16:31:16      0.0      0.0
# 3    user_954  2019-01-01 17:17:51      0.0      0.0
# 4    user_954  2019-01-01 21:31:18      0.0      0.0
# ..        ...                  ...      ...      ...
# 995  user_984   2019-04-20 9:59:58   9754.0      0.0
# 996       NaN                  NaN  10054.0  29265.0
# 997       NaN                  NaN  10454.0      0.0
# 998       NaN                  NaN   1000.0      0.0
# 999       NaN                  NaN  10754.0      0.0
#
# [1000 rows x 4 columns]

# %%
log.user_id.value_counts()
# Out:
# user_966    18
# user_972    16
# user_937    15
# user_983    15
# user_973    15
#             ..
# user_996     5
# user_915     5
# user_932     5
# user_945     5
# user_921     4
# Name: user_id, Length: 101, dtype: int64

# %%
def new_1(win, bet):
    if win < 0:
        return win
    else:
        return win - bet

# %%
log['net'] = log.apply(lambda x: new_1(x['win'],x['bet']), axis=1)

# %%
log
# Out:
#       user_id                 time      bet      win      net
# 0    user_919  2019-01-01 14:06:51      0.0      0.0      0.0
# 1    user_973  2019-01-01 14:51:16      0.0      0.0      0.0
# 2    user_903  2019-01-01 16:31:16      0.0      0.0      0.0
# 3    user_954  2019-01-01 17:17:51      0.0      0.0      0.0
# 4    user_954  2019-01-01 21:31:18      0.0      0.0      0.0
# ..        ...                  ...      ...      ...      ...
# 995  user_984   2019-04-20 9:59:58   9754.0      0.0  -9754.0
# 996       NaN                  NaN  10054.0  29265.0  19211.0
# 997       NaN                  NaN  10454.0      0.0 -10454.0
# 998       NaN                  NaN   1000.0      0.0  -1000.0
# 999       NaN                  NaN  10754.0      0.0 -10754.0
#
# [1000 rows x 5 columns]

# %%
us = pd.read_csv('users_1.csv', encoding='KOI8-R', sep=';')
us.columns = ['user_id', 'email', 'geo']
us
# Out:
#      user_id                     email          geo
# 0   User_943       Accumanst@gmail.com       Ижевск
# 1   User_908         Advismowr@mail.ru       Ижевск
# 2   User_962           Anachso@ukr.net    Краснодар
# 3   User_973          Antecia@inbox.ru        Пермь
# 4   User_902        Balliaryva@ukr.net          NaN
# ..       ...                       ...          ...
# 95  User_959  UpdatesCurious@yahoo.com       Тюмень
# 96  User_901        V2artierso@mail.ru  Арзангелтск
# 97  User_970          Vashoterlo@bk.ru      Воронеж
# 98  User_965       Visuareda@yahoo.com      Воронеж
# 99  User_921              Aavast@ya.ru       Ижевск
#
# [100 rows x 3 columns]

# %%
us['user_id'] = us['user_id'].str.lower()
us
# Out:
#      user_id                     email          geo
# 0   user_943       Accumanst@gmail.com       Ижевск
# 1   user_908         Advismowr@mail.ru       Ижевск
# 2   user_962           Anachso@ukr.net    Краснодар
# 3   user_973          Antecia@inbox.ru        Пермь
# 4   user_902        Balliaryva@ukr.net          NaN
# ..       ...                       ...          ...
# 95  user_959  UpdatesCurious@yahoo.com       Тюмень
# 96  user_901        V2artierso@mail.ru  Арзангелтск
# 97  user_970          Vashoterlo@bk.ru      Воронеж
# 98  user_965       Visuareda@yahoo.com      Воронеж
# 99  user_921              Aavast@ya.ru       Ижевск
#
# [100 rows x 3 columns]

# %%
table = pd.merge(log, us, on='user_id')
table
# Out:
#       user_id                 time    bet     win     net  \
# 0    user_919  2019-01-01 14:06:51    0.0     0.0     0.0
# 1    user_919  2019-01-30 10:06:00    0.0     0.0     0.0
# 2    user_919  2019-02-05 14:33:44    0.0     0.0     0.0
# 3    user_919  2019-02-14 11:38:05    0.0     0.0     0.0
# 4    user_919   2019-03-02 4:23:36  300.0     0.0  -300.0
# ..        ...                  ...    ...     ...     ...
# 970  user_932  2019-02-24 22:40:06    0.0     0.0     0.0
# 971  user_932  2019-03-15 10:56:14    0.0     0.0     0.0
# 972  user_932  2019-03-18 10:13:24    0.0     0.0     0.0
# 973  user_932  2019-03-27 12:18:24    0.0     0.0     0.0
# 974  user_932  2019-04-18 14:55:26  700.0  6640.0  5940.0
#
#                       email         geo
# 0    Chikkaverle@icloud.com   Хабаровск
# 1    Chikkaverle@icloud.com   Хабаровск
# 2    Chikkaverle@icloud.com   Хабаровск
# 3    Chikkaverle@icloud.com   Хабаровск
# 4    Chikkaverle@icloud.com   Хабаровск
# ...

# %% [markdown]
# Посчитайте медиану баланса по каждому пользователю. Для этого сгруппируйте по пользователям, возьмите признак net, просуммируйте по каждому пользователю и получите медиану.

# %%
table.groupby(['user_id']).sum().median()
# Out:
# bet    4100.0
# win    6482.0
# net    1986.0
# dtype: float64

# %% [markdown]
# Сколько раз в среднем каждый человек приходит, не делая ставок, при условии, что у этого человека все-таки есть хотя бы одна ставка? Например: Человек посетил букмекерскую контору 5 раз из них 1 раз сделал ставку, 4 раза нет - условие выполняется. Человек посетил букмекерскую контору 5 раз из них ни разу ставку не сделал - условие не выполняется. Для того, чтобы узнать это, просуммируйте в каждой группе количество записей со ставкой, равной 0, и поделите на общее количество групп. Если при этом в группе нет записей со ставкой больше 0, считаем количество записей в данной группе равным 0.

# %%
table.groupby(['user_id', 'bet']).count()
# Out:
#                    time  win  net  email  geo
# user_id   bet
# user_1000 0.0         8    8    8      8    8
#           100.0       1    1    1      1    1
#           300.0       1    1    1      1    1
#           400.0       1    1    1      1    1
#           800.0       1    1    1      1    1
# ...                 ...  ...  ...    ...  ...
# user_998  10654.0     1    1    1      1    1
# user_999  0.0         5    5    5      5    5
#           100.0       1    1    1      1    1
#           700.0       1    1    1      1    1
#           800.0       1    1    1      1    1
#
# [506 rows x 5 columns]

# %%
# после преобразований объединили данные из двух файлов
users_log = pd.merge(log, users, on ='user_id')
# создаем два датафрейма для подсчета случаев нулевой ставки
group = users_log[users_log.bet==0].groupby('user_id').bet.count() 
group_not_null = users_log[users_log.bet>0].groupby('user_id').bet.count()
# и объединяем по user_id
joined=pd.merge(group, group_not_null, on=['user_id'])
# Оставим только те строки, в которых у посетителя была хотя бы одна ставка
joined = joined[joined['bet_y']>0]
# И посчитаем среднее количество приходов без ставки
joined['bet_x'].sum()/len(joined)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-1c312177bae3> in <module>
#       1 # после преобразований объединили данные из двух файлов
# ----> 2 users_log = pd.merge(log, users, on ='user_id')
#       3 # создаем два датафрейма для подсчета случаев нулевой ставки
#       4 group = users_log[users_log.bet==0].groupby('user_id').bet.count()
#       5 group_not_null = users_log[users_log.bet>0].groupby('user_id').bet.count()
#
# NameError: name 'users' is not defined

# %%
group_table_0 = table[table['bet']==0].groupby('user_id').bet.count()
group_table_0
# Out:
# user_id
# user_1000    8
# user_900     6
# user_901     6
# user_902     4
# user_903     4
#             ..
# user_995     4
# user_996     2
# user_997     4
# user_998     3
# user_999     5
# Name: bet, Length: 100, dtype: int64

# %%
group_table_not_null = table[table['bet']>0].groupby('user_id').bet.count()
group_table_not_null
# Out:
# user_id
# user_1000    4
# user_900     8
# user_901     2
# user_902     4
# user_903     5
#             ..
# user_995     6
# user_996     3
# user_997     2
# user_998     8
# user_999     3
# Name: bet, Length: 100, dtype: int64

# %%
joined=pd.merge(group_table_0, group_table_not_null, on=['user_id'])
joined
# Out:
#            bet_x  bet_y
# user_id
# user_1000      8      4
# user_900       6      8
# user_901       6      2
# user_902       4      4
# user_903       4      5
# ...          ...    ...
# user_995       4      6
# user_996       2      3
# user_997       4      2
# user_998       3      8
# user_999       5      3
#
# [100 rows x 2 columns]

# %%
joined = joined[joined['bet_y']>0]
joined
# Out:
#            bet_x  bet_y
# user_id
# user_1000      8      4
# user_900       6      8
# user_901       6      2
# user_902       4      4
# user_903       4      5
# ...          ...    ...
# user_995       4      6
# user_996       2      3
# user_997       4      2
# user_998       3      8
# user_999       5      3
#
# [100 rows x 2 columns]

# %%
joined['bet_x'].sum()/len(joined)
# Out:
# 5.05

# %% [markdown]
# Сколько в среднем времени проходит между появлением человека в сервисе и первой ставкой? Считать нужно только тех, кто делал ставку. Для того, чтобы узнать это, напишите метод, считающий минимальное время среди ставок, равных 0, и минимальное время среди ставок больше 0. После этого верните разницу между вторым и первым числом. Пройдитесь по всем группам. Если в группе нет ставок больше 0, пропустите эту группу. Просуммируйте разницу во времени для каждой группы (с помощью метода, описанного выше) и поделите на количество групп, которые вы не пропустили.
# Например, если ваш результат Timedelta('23 days 12:24:32'), то в поле пишите 23.

# %%
table
# Out:
#       user_id                 time    bet     win     net  \
# 0    user_919  2019-01-01 14:06:51    0.0     0.0     0.0
# 1    user_919  2019-01-30 10:06:00    0.0     0.0     0.0
# 2    user_919  2019-02-05 14:33:44    0.0     0.0     0.0
# 3    user_919  2019-02-14 11:38:05    0.0     0.0     0.0
# 4    user_919   2019-03-02 4:23:36  300.0     0.0  -300.0
# ..        ...                  ...    ...     ...     ...
# 970  user_932  2019-02-24 22:40:06    0.0     0.0     0.0
# 971  user_932  2019-03-15 10:56:14    0.0     0.0     0.0
# 972  user_932  2019-03-18 10:13:24    0.0     0.0     0.0
# 973  user_932  2019-03-27 12:18:24    0.0     0.0     0.0
# 974  user_932  2019-04-18 14:55:26  700.0  6640.0  5940.0
#
#                       email         geo
# 0    Chikkaverle@icloud.com   Хабаровск
# 1    Chikkaverle@icloud.com   Хабаровск
# 2    Chikkaverle@icloud.com   Хабаровск
# 3    Chikkaverle@icloud.com   Хабаровск
# 4    Chikkaverle@icloud.com   Хабаровск
# ...

# %%
type(table['time'])
# Out:
# pandas.core.series.Series

# %%
table['time'] = pd.to_datetime(table['time'])

# %%
type(table['time'])
# Out:
# pandas.core.series.Series

# %%
test = table.groupby(['user_id', 'time', 'bet']).count()
test
# Out:
#                                      win  net  email  geo
# user_id   time                bet
# user_1000 2019-01-21 19:31:34 0.0      1    1      1    1
#           2019-01-28 20:57:37 800.0    1    1      1    1
#           2019-02-10 05:33:25 0.0      1    1      1    1
#           2019-02-17 02:34:32 0.0      1    1      1    1
#           2019-02-21 12:01:29 0.0      1    1      1    1
# ...                                  ...  ...    ...  ...
# user_999  2019-02-22 10:47:12 0.0      1    1      1    1
#           2019-02-23 08:45:49 0.0      1    1      1    1
#           2019-03-15 22:50:47 100.0    1    1      1    1
#           2019-03-22 02:34:01 700.0    1    1      1    1
#           2019-03-22 04:14:12 800.0    1    1      1    1
#
# [975 rows x 4 columns]

# %%
group_users = table.groupby(['user_id'])

# %%
# group_users[(group_users['time'].min()) & (group_users['bet'] == 0)]

# %%
group_users

# %%
table
# Out:
#       user_id                time    bet     win     net  \
# 0    user_919 2019-01-01 14:06:51    0.0     0.0     0.0
# 1    user_919 2019-01-30 10:06:00    0.0     0.0     0.0
# 2    user_919 2019-02-05 14:33:44    0.0     0.0     0.0
# 3    user_919 2019-02-14 11:38:05    0.0     0.0     0.0
# 4    user_919 2019-03-02 04:23:36  300.0     0.0  -300.0
# ..        ...                 ...    ...     ...     ...
# 970  user_932 2019-02-24 22:40:06    0.0     0.0     0.0
# 971  user_932 2019-03-15 10:56:14    0.0     0.0     0.0
# 972  user_932 2019-03-18 10:13:24    0.0     0.0     0.0
# 973  user_932 2019-03-27 12:18:24    0.0     0.0     0.0
# 974  user_932 2019-04-18 14:55:26  700.0  6640.0  5940.0
#
#                       email         geo
# 0    Chikkaverle@icloud.com   Хабаровск
# 1    Chikkaverle@icloud.com   Хабаровск
# 2    Chikkaverle@icloud.com   Хабаровск
# 3    Chikkaverle@icloud.com   Хабаровск
# 4    Chikkaverle@icloud.com   Хабаровск
# ...

# %%
hz = table[table['bet']==0]

# %%
hz
# Out:
#       user_id                time  bet  win  net                   email  \
# 0    user_919 2019-01-01 14:06:51  0.0  0.0  0.0  Chikkaverle@icloud.com
# 1    user_919 2019-01-30 10:06:00  0.0  0.0  0.0  Chikkaverle@icloud.com
# 2    user_919 2019-02-05 14:33:44  0.0  0.0  0.0  Chikkaverle@icloud.com
# 3    user_919 2019-02-14 11:38:05  0.0  0.0  0.0  Chikkaverle@icloud.com
# 8    user_973 2019-01-01 14:51:16  0.0  0.0  0.0        Antecia@inbox.ru
# ..        ...                 ...  ...  ...  ...                     ...
# 967  user_934 2019-03-23 23:38:27  0.0  0.0  0.0        EyesRae@inbox.ru
# 970  user_932 2019-02-24 22:40:06  0.0  0.0  0.0       BraceWalker@bk.ru
# 971  user_932 2019-03-15 10:56:14  0.0  0.0  0.0       BraceWalker@bk.ru
# 972  user_932 2019-03-18 10:13:24  0.0  0.0  0.0       BraceWalker@bk.ru
# 973  user_932 2019-03-27 12:18:24  0.0  0.0  0.0       BraceWalker@bk.ru
#
#              geo
# 0      Хабаровск
# 1      Хабаровск
# 2      Хабаровск
# 3      Хабаровск
# ...

# %%
group_table_0 = table[table['bet']==0].groupby('user_id').bet.count()
group_table_0

group_table_not_null = table[table['bet']>0].groupby('user_id').bet.count()
group_table_not_null

joined=pd.merge(group_table_0, group_table_not_null, on=['user_id'])
joined

joined = joined[joined['bet_y']>0]
joined
# Out:
#            bet_x  bet_y
# user_id
# user_1000      8      4
# user_900       6      8
# user_901       6      2
# user_902       4      4
# user_903       4      5
# ...          ...    ...
# user_995       4      6
# user_996       2      3
# user_997       4      2
# user_998       3      8
# user_999       5      3
#
# [100 rows x 2 columns]

# %%
hz_0 = table[(table['bet']==0)].groupby(['user_id', 'time']).bet.count()
hz_0
# Out:
# user_id    time
# user_1000  2019-01-21 19:31:34    1
#            2019-02-10 05:33:25    1
#            2019-02-17 02:34:32    1
#            2019-02-21 12:01:29    1
#            2019-03-02 17:17:13    1
#                                  ..
# user_999   2019-01-07 10:07:52    1
#            2019-02-02 15:28:36    1
#            2019-02-10 12:30:22    1
#            2019-02-22 10:47:12    1
#            2019-02-23 08:45:49    1
# Name: bet, Length: 505, dtype: int64

# %%
table[(table['bet']==0) & ]
# Out:
#   File "<ipython-input-103-45148e7ccd6e>", line 1
#     table[(table['bet']==0) & ]
#                               ^
# SyntaxError: invalid syntax

# %%
hz = table[table['bet']>0].groupby(['user_id', 'time']).bet.count()
hz
# Out:
# user_id    time
# user_1000  2019-01-28 20:57:37    1
#            2019-03-27 03:39:36    1
#            2019-04-05 06:48:33    1
#            2019-04-05 14:45:54    1
# user_900   2019-02-08 10:36:47    1
#                                  ..
# user_998   2019-04-03 15:02:50    1
#            2019-04-06 06:08:40    1
# user_999   2019-03-15 22:50:47    1
#            2019-03-22 02:34:01    1
#            2019-03-22 04:14:12    1
# Name: bet, Length: 470, dtype: int64

# %% [markdown]
# # 12.9.3

# %%
bet_0_time = table[table['bet']==0]

# %%
bet_0_time
# Out:
#       user_id                time  bet  win  net                   email  \
# 0    user_919 2019-01-01 14:06:51  0.0  0.0  0.0  Chikkaverle@icloud.com
# 1    user_919 2019-01-30 10:06:00  0.0  0.0  0.0  Chikkaverle@icloud.com
# 2    user_919 2019-02-05 14:33:44  0.0  0.0  0.0  Chikkaverle@icloud.com
# 3    user_919 2019-02-14 11:38:05  0.0  0.0  0.0  Chikkaverle@icloud.com
# 8    user_973 2019-01-01 14:51:16  0.0  0.0  0.0        Antecia@inbox.ru
# ..        ...                 ...  ...  ...  ...                     ...
# 967  user_934 2019-03-23 23:38:27  0.0  0.0  0.0        EyesRae@inbox.ru
# 970  user_932 2019-02-24 22:40:06  0.0  0.0  0.0       BraceWalker@bk.ru
# 971  user_932 2019-03-15 10:56:14  0.0  0.0  0.0       BraceWalker@bk.ru
# 972  user_932 2019-03-18 10:13:24  0.0  0.0  0.0       BraceWalker@bk.ru
# 973  user_932 2019-03-27 12:18:24  0.0  0.0  0.0       BraceWalker@bk.ru
#
#              geo
# 0      Хабаровск
# 1      Хабаровск
# 2      Хабаровск
# 3      Хабаровск
# ...

# %%
bet_min_time_0 = bet_0_time.groupby(['user_id']).time.min()

# %%
bet_min_time_0
# Out:
# user_id
# user_1000   2019-01-21 19:31:34
# user_900    2019-01-01 04:37:25
# user_901    2019-01-07 08:45:59
# user_902    2019-01-28 03:12:06
# user_903    2019-01-01 16:31:16
#                     ...
# user_995    2019-01-07 09:56:20
# user_996    2019-03-03 11:43:38
# user_997    2019-01-05 20:55:29
# user_998    2019-01-03 02:48:25
# user_999    2019-01-07 10:07:52
# Name: time, Length: 100, dtype: datetime64[ns]

# %%
bet_not_0_time = table[table['bet']!=0]

# %%
bet_not_0_time
# Out:
#       user_id                time      bet     win      net  \
# 4    user_919 2019-03-02 04:23:36    300.0     0.0   -300.0
# 5    user_919 2019-03-30 10:17:51    400.0  5737.0   5337.0
# 6    user_919 2019-04-03 02:09:44    600.0     0.0   -600.0
# 7    user_919 2019-04-16 00:53:16    700.0     0.0   -700.0
# 16   user_973 2019-02-15 20:10:37    100.0     0.0   -100.0
# ..        ...                 ...      ...     ...      ...
# 956  user_925 2019-03-17 08:46:12    200.0     0.0   -200.0
# 957  user_925 2019-04-20 12:55:00   1000.0     0.0  -1000.0
# 968  user_934 2019-04-12 06:47:38    300.0     0.0   -300.0
# 969  user_934 2019-04-15 03:26:43  10554.0     0.0 -10554.0
# 974  user_932 2019-04-18 14:55:26    700.0  6640.0   5940.0
#
#                       email          geo
# 4    Chikkaverle@icloud.com    Хабаровск
# 5    Chikkaverle@icloud.com    Хабаровск
# 6    Chikkaverle@icloud.com    Хабаровск
# 7    Chikkaverle@icloud.com    Хабаровск
# ...

# %%
bet_min_time = bet_not_0_time.groupby(['user_id']).time.min()

# %%
bet_min_time
# Out:
# user_id
# user_1000   2019-01-28 20:57:37
# user_900    2019-02-08 10:36:47
# user_901    2019-03-14 13:51:20
# user_902    2019-03-09 16:52:11
# user_903    2019-02-08 11:06:00
#                     ...
# user_995    2019-02-26 15:29:25
# user_996    2019-01-10 07:32:17
# user_997    2019-03-05 11:05:39
# user_998    2019-01-25 08:57:20
# user_999    2019-03-15 22:50:47
# Name: time, Length: 100, dtype: datetime64[ns]

# %%
times = pd.concat([bet_min_time_0, bet_min_time], axis = 1, sort=False )

# %%
times
# Out:
#                          time                time
# user_id
# user_1000 2019-01-21 19:31:34 2019-01-28 20:57:37
# user_900  2019-01-01 04:37:25 2019-02-08 10:36:47
# user_901  2019-01-07 08:45:59 2019-03-14 13:51:20
# user_902  2019-01-28 03:12:06 2019-03-09 16:52:11
# user_903  2019-01-01 16:31:16 2019-02-08 11:06:00
# ...                       ...                 ...
# user_995  2019-01-07 09:56:20 2019-02-26 15:29:25
# user_996  2019-03-03 11:43:38 2019-01-10 07:32:17
# user_997  2019-01-05 20:55:29 2019-03-05 11:05:39
# user_998  2019-01-03 02:48:25 2019-01-25 08:57:20
# user_999  2019-01-07 10:07:52 2019-03-15 22:50:47
#
# [100 rows x 2 columns]

# %%
times.columns
# Out:
# Index(['time', 'time'], dtype='object')

# %%
times['time']
# Out:
#                          time                time
# user_id
# user_1000 2019-01-21 19:31:34 2019-01-28 20:57:37
# user_900  2019-01-01 04:37:25 2019-02-08 10:36:47
# user_901  2019-01-07 08:45:59 2019-03-14 13:51:20
# user_902  2019-01-28 03:12:06 2019-03-09 16:52:11
# user_903  2019-01-01 16:31:16 2019-02-08 11:06:00
# ...                       ...                 ...
# user_995  2019-01-07 09:56:20 2019-02-26 15:29:25
# user_996  2019-03-03 11:43:38 2019-01-10 07:32:17
# user_997  2019-01-05 20:55:29 2019-03-05 11:05:39
# user_998  2019-01-03 02:48:25 2019-01-25 08:57:20
# user_999  2019-01-07 10:07:52 2019-03-15 22:50:47
#
# [100 rows x 2 columns]

# %%
times = times.rename(columns={times.columns[0]: 'time_0', times.columns[1]: 'time_bet'})

# %%
times
# Out:
#                      time_bet            time_bet
# user_id
# user_1000 2019-01-21 19:31:34 2019-01-28 20:57:37
# user_900  2019-01-01 04:37:25 2019-02-08 10:36:47
# user_901  2019-01-07 08:45:59 2019-03-14 13:51:20
# user_902  2019-01-28 03:12:06 2019-03-09 16:52:11
# user_903  2019-01-01 16:31:16 2019-02-08 11:06:00
# ...                       ...                 ...
# user_995  2019-01-07 09:56:20 2019-02-26 15:29:25
# user_996  2019-03-03 11:43:38 2019-01-10 07:32:17
# user_997  2019-01-05 20:55:29 2019-03-05 11:05:39
# user_998  2019-01-03 02:48:25 2019-01-25 08:57:20
# user_999  2019-01-07 10:07:52 2019-03-15 22:50:47
#
# [100 rows x 2 columns]

# %%
times['new_time'] = (times.columns[0].to_date) - (times.columns[1].to_date)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-f8b792a8989f> in <module>
# ----> 1 times['new_time'] = (times.columns[0].to_date) - (times.columns[1].to_date)
#
# AttributeError: 'str' object has no attribute 'to_date'

# %%
times.columns[0]
# Out:
# 'time_bet'

# %%
times.columns[0:2]
# Out:
# Index(['time_bet', 'time_bet'], dtype='object')

# %%
times.columns[]
# Out:
#   File "<ipython-input-122-59b8f5a35da6>", line 1
#     times.columns[]
#                   ^
# SyntaxError: invalid syntax

# %%
times.columns
# Out:
# Index(['time_bet', 'time_bet'], dtype='object')

# %%
times
# Out:
#                      time_bet            time_bet
# user_id
# user_1000 2019-01-21 19:31:34 2019-01-28 20:57:37
# user_900  2019-01-01 04:37:25 2019-02-08 10:36:47
# user_901  2019-01-07 08:45:59 2019-03-14 13:51:20
# user_902  2019-01-28 03:12:06 2019-03-09 16:52:11
# user_903  2019-01-01 16:31:16 2019-02-08 11:06:00
# ...                       ...                 ...
# user_995  2019-01-07 09:56:20 2019-02-26 15:29:25
# user_996  2019-03-03 11:43:38 2019-01-10 07:32:17
# user_997  2019-01-05 20:55:29 2019-03-05 11:05:39
# user_998  2019-01-03 02:48:25 2019-01-25 08:57:20
# user_999  2019-01-07 10:07:52 2019-03-15 22:50:47
#
# [100 rows x 2 columns]

# %%
times.columns = ['time_0', 'time_bet']

# %%
times
# Out:
#                        time_0            time_bet
# user_id
# user_1000 2019-01-21 19:31:34 2019-01-28 20:57:37
# user_900  2019-01-01 04:37:25 2019-02-08 10:36:47
# user_901  2019-01-07 08:45:59 2019-03-14 13:51:20
# user_902  2019-01-28 03:12:06 2019-03-09 16:52:11
# user_903  2019-01-01 16:31:16 2019-02-08 11:06:00
# ...                       ...                 ...
# user_995  2019-01-07 09:56:20 2019-02-26 15:29:25
# user_996  2019-03-03 11:43:38 2019-01-10 07:32:17
# user_997  2019-01-05 20:55:29 2019-03-05 11:05:39
# user_998  2019-01-03 02:48:25 2019-01-25 08:57:20
# user_999  2019-01-07 10:07:52 2019-03-15 22:50:47
#
# [100 rows x 2 columns]

# %%
times['new_time'] = times['time_bet'] - times['time_0']

# %%
times
# Out:
#                        time_0            time_bet           new_time
# user_id
# user_1000 2019-01-21 19:31:34 2019-01-28 20:57:37    7 days 01:26:03
# user_900  2019-01-01 04:37:25 2019-02-08 10:36:47   38 days 05:59:22
# user_901  2019-01-07 08:45:59 2019-03-14 13:51:20   66 days 05:05:21
# user_902  2019-01-28 03:12:06 2019-03-09 16:52:11   40 days 13:40:05
# user_903  2019-01-01 16:31:16 2019-02-08 11:06:00   37 days 18:34:44
# ...                       ...                 ...                ...
# user_995  2019-01-07 09:56:20 2019-02-26 15:29:25   50 days 05:33:05
# user_996  2019-03-03 11:43:38 2019-01-10 07:32:17 -53 days +19:48:39
# user_997  2019-01-05 20:55:29 2019-03-05 11:05:39   58 days 14:10:10
# user_998  2019-01-03 02:48:25 2019-01-25 08:57:20   22 days 06:08:55
# user_999  2019-01-07 10:07:52 2019-03-15 22:50:47   67 days 12:42:55
#
# [100 rows x 3 columns]

# %%
times['new_time'].sum()
# Out:
# Timedelta('4628 days 19:20:00')

# %%
times['new_time'].count()
# Out:
# 100

# %%
table
# Out:
#       user_id                time    bet     win     net  \
# 0    user_919 2019-01-01 14:06:51    0.0     0.0     0.0
# 1    user_919 2019-01-30 10:06:00    0.0     0.0     0.0
# 2    user_919 2019-02-05 14:33:44    0.0     0.0     0.0
# 3    user_919 2019-02-14 11:38:05    0.0     0.0     0.0
# 4    user_919 2019-03-02 04:23:36  300.0     0.0  -300.0
# ..        ...                 ...    ...     ...     ...
# 970  user_932 2019-02-24 22:40:06    0.0     0.0     0.0
# 971  user_932 2019-03-15 10:56:14    0.0     0.0     0.0
# 972  user_932 2019-03-18 10:13:24    0.0     0.0     0.0
# 973  user_932 2019-03-27 12:18:24    0.0     0.0     0.0
# 974  user_932 2019-04-18 14:55:26  700.0  6640.0  5940.0
#
#                       email         geo
# 0    Chikkaverle@icloud.com   Хабаровск
# 1    Chikkaverle@icloud.com   Хабаровск
# 2    Chikkaverle@icloud.com   Хабаровск
# 3    Chikkaverle@icloud.com   Хабаровск
# 4    Chikkaverle@icloud.com   Хабаровск
# ...

# %%
table.groupby(['geo']).win.sum(ascending=False)
# Out:
# geo
# Арзангелтск           74375.0
# Воронеж              184338.0
# Екатеринбург          36682.0
# Ижевск                84895.0
# Казань                97806.0
# Краснодар             62718.0
# Красноярск            84767.0
# Москва             11959741.0
# Пермь                 67734.0
# Санкт-Петербург      151007.0
# Ставрополь            46003.0
# Тюмень                 4701.0
# Хабаровск             65459.0
# Ярославль             97441.0
# Name: win, dtype: float64

# %%
bet_city = table[table['bet']>0]
bet_city
# Out:
#       user_id                time      bet     win      net  \
# 4    user_919 2019-03-02 04:23:36    300.0     0.0   -300.0
# 5    user_919 2019-03-30 10:17:51    400.0  5737.0   5337.0
# 6    user_919 2019-04-03 02:09:44    600.0     0.0   -600.0
# 7    user_919 2019-04-16 00:53:16    700.0     0.0   -700.0
# 16   user_973 2019-02-15 20:10:37    100.0     0.0   -100.0
# ..        ...                 ...      ...     ...      ...
# 956  user_925 2019-03-17 08:46:12    200.0     0.0   -200.0
# 957  user_925 2019-04-20 12:55:00   1000.0     0.0  -1000.0
# 968  user_934 2019-04-12 06:47:38    300.0     0.0   -300.0
# 969  user_934 2019-04-15 03:26:43  10554.0     0.0 -10554.0
# 974  user_932 2019-04-18 14:55:26    700.0  6640.0   5940.0
#
#                       email          geo
# 4    Chikkaverle@icloud.com    Хабаровск
# 5    Chikkaverle@icloud.com    Хабаровск
# 6    Chikkaverle@icloud.com    Хабаровск
# 7    Chikkaverle@icloud.com    Хабаровск
# ...

# %%
a = bet_city.groupby(['geo']).bet.max()

# %%
b = bet_city.groupby(['geo']).bet.min()

# %%
#times = pd.concat([bet_min_time_0, bet_min_time], axis = 1, sort=False )

# %%
c = pd.concat([a, b], axis = 1, sort=False)

# %%
c
# Out:
#                        bet    bet
# geo
# Арзангелтск        10554.0  100.0
# Воронеж            10754.0  100.0
# Екатеринбург         900.0  100.0
# Ижевск             10654.0  100.0
# Казань             10654.0  100.0
# Краснодар          10354.0  100.0
# Красноярск         10554.0  100.0
# Москва           1678321.0  100.0
# Пермь              10754.0  100.0
# Санкт-Петербург    10754.0  100.0
# Ставрополь         10254.0  100.0
# Тюмень              1000.0  100.0
# Хабаровск          10754.0  100.0
# Ярославль          10554.0  100.0

# %%
c.columns = ['bet_max', 'bet_min']

# %%
c
# Out:
#                    bet_max  bet_min
# geo
# Арзангелтск        10554.0    100.0
# Воронеж            10754.0    100.0
# Екатеринбург         900.0    100.0
# Ижевск             10654.0    100.0
# Казань             10654.0    100.0
# Краснодар          10354.0    100.0
# Красноярск         10554.0    100.0
# Москва           1678321.0    100.0
# Пермь              10754.0    100.0
# Санкт-Петербург    10754.0    100.0
# Ставрополь         10254.0    100.0
# Тюмень              1000.0    100.0
# Хабаровск          10754.0    100.0
# Ярославль          10554.0    100.0

# %%
c['bet_sred'] = c['bet_max'] / c['bet_min']

# %%
c
# Out:
#                    bet_max  bet_min  bet_sred
# geo
# Арзангелтск        10554.0    100.0    105.54
# Воронеж            10754.0    100.0    107.54
# Екатеринбург         900.0    100.0      9.00
# Ижевск             10654.0    100.0    106.54
# Казань             10654.0    100.0    106.54
# Краснодар          10354.0    100.0    103.54
# Красноярск         10554.0    100.0    105.54
# Москва           1678321.0    100.0  16783.21
# Пермь              10754.0    100.0    107.54
# Санкт-Петербург    10754.0    100.0    107.54
# Ставрополь         10254.0    100.0    102.54
# Тюмень              1000.0    100.0     10.00
# Хабаровск          10754.0    100.0    107.54
# Ярославль          10554.0    100.0    105.54

# %%
c['bet_sred'].median()
# Out:
# 106.04
